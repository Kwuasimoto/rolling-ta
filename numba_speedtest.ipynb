# %%
from rolling_ta.data import CSVLoader


import numpy as np
import numba as nb
from numba.types import Array, i4, f8

import pandas as pd

# %%
csv_loader = CSVLoader()
btc_data = csv_loader.read_resource()
# Out:
# DEBUG - CSVLoader: Loading from resources/btc_ohlcv.csv

# %%
btc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  10000 non-null  float64
#  1   open       10000 non-null  float64
#  2   high       10000 non-null  float64
#  3   low        10000 non-null  float64
#  4   close      10000 non-null  float64
#  5   volume     10000 non-null  float64
# dtypes: float64(6)
# memory usage: 468.9 KB

# %% [markdown]
# ## Native Python Test
# *With pandas / numpy*

# %%
# Define function
def sma_native(data: pd.Series, period=14):
    n = data.shape[0]
    sma = list(0 for _ in range(n))
    
    for i in range(n):
        sma[i] = sum(data[i:i + period]) / period
        
    return sma

# %%
# %%timeit
sma_native(btc_data["close"])
# Out:
# 126 ms ± 2.75 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# # Pandas Vectorized Test

# %%
def sma_vectorized(data: pd.Series, period=14):
    return data.rolling(period, min_periods=period).sum()

# %%
# %%timeit
sma_vectorized(btc_data["close"])
# Out:
# 239 μs ± 6.46 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %% [markdown]
# ## Numba Test
# *Jesus take the wheel*

# %%
@nb.njit
def sma_numba(data: np.ndarray[f8], period: i4 = 14) -> np.ndarray[f8]:
    sma = np.zeros_like(data, dtype=np.float64)
    
    for i in range(sma.shape[0] - period):
        sma[i + period] = np.sum(data[i:i+period]) / period
    
    return sma

# %%
# %%timeit
sma_numba(btc_data["close"].values)
# Out:
# DEBUG - bytecode dump:
# >          0	NOP(arg=None, lineno=1)
#            2	RESUME(arg=0, lineno=1)
#            4	LOAD_GLOBAL(arg=0, lineno=3)
#           14	LOAD_ATTR(arg=3, lineno=3)
#           34	LOAD_FAST(arg=0, lineno=3)
#           36	LOAD_GLOBAL(arg=0, lineno=3)
#           46	LOAD_ATTR(arg=4, lineno=3)
#           66	KW_NAMES(arg=1, lineno=3)
#           68	CALL(arg=2, lineno=3)
#           76	STORE_FAST(arg=2, lineno=3)
#           78	LOAD_GLOBAL(arg=7, lineno=5)
#           88	LOAD_FAST(arg=2, lineno=5)
#           90	LOAD_ATTR(arg=8, lineno=5)
#          110	LOAD_CONST(arg=2, lineno=5)
#          112	BINARY_SUBSCR(arg=None, lineno=5)
#          116	LOAD_FAST(arg=1, lineno=5)
#          118	BINARY_OP(arg=10, lineno=5)
#          122	CALL(arg=1, lineno=5)
#          130	GET_ITER(arg=None, lineno=5)
# >        132	FOR_ITER(arg=38, lineno=5)
#          136	STORE_FAST(arg=3, lineno=5)
#          138	LOAD_GLOBAL(arg=0, lineno=6)
#          148	LOAD_ATTR(arg=11, lineno=6)
#          168	LOAD_FAST(arg=0, lineno=6)
#          170	LOAD_FAST(arg=3, lineno=6)
#          172	LOAD_FAST(arg=3, lineno=6)
#          174	LOAD_FAST(arg=1, lineno=6)
#          176	BINARY_OP(arg=0, lineno=6)
#          180	BINARY_SLICE(arg=None, lineno=6)
#          182	CALL(arg=1, lineno=6)
#          190	LOAD_FAST(arg=1, lineno=6)
#          192	BINARY_OP(arg=11, lineno=6)
#          196	LOAD_FAST(arg=2, lineno=6)
#          198	LOAD_FAST(arg=3, lineno=6)
#          200	LOAD_FAST(arg=1, lineno=6)
#          202	BINARY_OP(arg=0, lineno=6)
#          206	STORE_SUBSCR(arg=None, lineno=6)
#          210	JUMP_BACKWARD(arg=40, lineno=6)
# >        212	END_FOR(arg=None, lineno=5)
#          214	LOAD_FAST(arg=2, lineno=8)
#          216	RETURN_VALUE(arg=None, lineno=8)
# DEBUG - pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG - stack: []
# DEBUG - state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG - dispatch pc=0, inst=NOP(arg=None, lineno=1)
# DEBUG - stack []
# DEBUG - dispatch pc=2, inst=RESUME(arg=0, lineno=1)
# DEBUG - stack []
# DEBUG - dispatch pc=4, inst=LOAD_GLOBAL(arg=0, lineno=3)
# DEBUG - stack []
# DEBUG - dispatch pc=14, inst=LOAD_ATTR(arg=3, lineno=3)
# DEBUG - stack ['$4load_global.0']
# DEBUG - dispatch pc=34, inst=LOAD_FAST(arg=0, lineno=3)
# DEBUG - stack ['$null$14.1', '$14load_attr.2']
# DEBUG - dispatch pc=36, inst=LOAD_GLOBAL(arg=0, lineno=3)
# DEBUG - stack ['$null$14.1', '$14load_attr.2', '$data34.3']
# DEBUG - dispatch pc=46, inst=LOAD_ATTR(arg=4, lineno=3)
# DEBUG - stack ['$null$14.1', '$14load_attr.2', '$data34.3', '$36load_global.4']
# DEBUG - dispatch pc=66, inst=KW_NAMES(arg=1, lineno=3)
# DEBUG - stack ['$null$14.1', '$14load_attr.2', '$data34.3', '$46load_attr.5']
# DEBUG - dispatch pc=68, inst=CALL(arg=2, lineno=3)
# DEBUG - stack ['$null$14.1', '$14load_attr.2', '$data34.3', '$46load_attr.5']
# DEBUG - dispatch pc=76, inst=STORE_FAST(arg=2, lineno=3)
# DEBUG - stack ['$68call.6']
# DEBUG - dispatch pc=78, inst=LOAD_GLOBAL(arg=7, lineno=5)
# DEBUG - stack []
# DEBUG - dispatch pc=88, inst=LOAD_FAST(arg=2, lineno=5)
# DEBUG - stack ['$null$78.8', '$78load_global.7']
# DEBUG - dispatch pc=90, inst=LOAD_ATTR(arg=8, lineno=5)
# DEBUG - stack ['$null$78.8', '$78load_global.7', '$sma88.9']
# DEBUG - dispatch pc=110, inst=LOAD_CONST(arg=2, lineno=5)
# DEBUG - stack ['$null$78.8', '$78load_global.7', '$90load_attr.10']
# DEBUG - dispatch pc=112, inst=BINARY_SUBSCR(arg=None, lineno=5)
# DEBUG - stack ['$null$78.8', '$78load_global.7', '$90load_attr.10', '$const110.11']
# DEBUG - dispatch pc=116, inst=LOAD_FAST(arg=1, lineno=5)
# DEBUG - stack ['$null$78.8', '$78load_global.7', '$112binary_subscr.12']
# DEBUG - dispatch pc=118, inst=BINARY_OP(arg=10, lineno=5)
# DEBUG - stack ['$null$78.8', '$78load_global.7', '$112binary_subscr.12', '$period116.13']
# DEBUG - dispatch pc=122, inst=CALL(arg=1, lineno=5)
# DEBUG - stack ['$null$78.8', '$78load_global.7', '$binop_sub118.14']
# DEBUG - dispatch pc=130, inst=GET_ITER(arg=None, lineno=5)
# DEBUG - stack ['$122call.15']
# DEBUG - end state. edges=[Edge(pc=132, stack=('$130get_iter.16',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=132 nstack_initial=1)])
# DEBUG - stack: ['$phi132.0']
# DEBUG - state.pc_initial: State(pc_initial=132 nstack_initial=1)
# DEBUG - dispatch pc=132, inst=FOR_ITER(arg=38, lineno=5)
# DEBUG - stack ['$phi132.0']
# DEBUG - end state. edges=[Edge(pc=212, stack=('$phi132.0', '$132for_iter.2'), blockstack=(), npush=0), Edge(pc=136, stack=('$phi132.0', '$132for_iter.2'), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=212 nstack_initial=2), State(pc_initial=136 nstack_initial=2)])
# DEBUG - stack: ['$phi212.0', '$phi212.1']
# DEBUG - state.pc_initial: State(pc_initial=212 nstack_initial=2)
# DEBUG - dispatch pc=212, inst=END_FOR(arg=None, lineno=5)
# DEBUG - stack ['$phi212.0', '$phi212.1']
# DEBUG - dispatch pc=214, inst=LOAD_FAST(arg=2, lineno=8)
# DEBUG - stack []
# DEBUG - dispatch pc=216, inst=RETURN_VALUE(arg=None, lineno=8)
# DEBUG - stack ['$sma214.2']
# DEBUG - end state. edges=[]
# DEBUG - pending: deque([State(pc_initial=136 nstack_initial=2)])
# DEBUG - stack: ['$phi136.0', '$phi136.1']
# DEBUG - state.pc_initial: State(pc_initial=136 nstack_initial=2)
# DEBUG - dispatch pc=136, inst=STORE_FAST(arg=3, lineno=5)
# DEBUG - stack ['$phi136.0', '$phi136.1']
# DEBUG - dispatch pc=138, inst=LOAD_GLOBAL(arg=0, lineno=6)
# DEBUG - stack ['$phi136.0']
# DEBUG - dispatch pc=148, inst=LOAD_ATTR(arg=11, lineno=6)
# DEBUG - stack ['$phi136.0', '$138load_global.2']
# DEBUG - dispatch pc=168, inst=LOAD_FAST(arg=0, lineno=6)
# DEBUG - stack ['$phi136.0', '$null$148.3', '$148load_attr.4']
# DEBUG - dispatch pc=170, inst=LOAD_FAST(arg=3, lineno=6)
# DEBUG - stack ['$phi136.0', '$null$148.3', '$148load_attr.4', '$data168.5']
# DEBUG - dispatch pc=172, inst=LOAD_FAST(arg=3, lineno=6)
# DEBUG - stack ['$phi136.0', '$null$148.3', '$148load_attr.4', '$data168.5', '$i170.6']
# DEBUG - dispatch pc=174, inst=LOAD_FAST(arg=1, lineno=6)
# DEBUG - stack ['$phi136.0', '$null$148.3', '$148load_attr.4', '$data168.5', '$i170.6', '$i172.7']
# DEBUG - dispatch pc=176, inst=BINARY_OP(arg=0, lineno=6)
# DEBUG - stack ['$phi136.0', '$null$148.3', '$148load_attr.4', '$data168.5', '$i170.6', '$i172.7', '$period174.8']
# DEBUG - dispatch pc=180, inst=BINARY_SLICE(arg=None, lineno=6)
# DEBUG - stack ['$phi136.0', '$null$148.3', '$148load_attr.4', '$data168.5', '$i170.6', '$binop_add176.9']
# DEBUG - dispatch pc=182, inst=CALL(arg=1, lineno=6)
# DEBUG - stack ['$phi136.0', '$null$148.3', '$148load_attr.4', '$180binary_slice.11']
# DEBUG - dispatch pc=190, inst=LOAD_FAST(arg=1, lineno=6)
# DEBUG - stack ['$phi136.0', '$182call.13']
# DEBUG - dispatch pc=192, inst=BINARY_OP(arg=11, lineno=6)
# DEBUG - stack ['$phi136.0', '$182call.13', '$period190.14']
# DEBUG - dispatch pc=196, inst=LOAD_FAST(arg=2, lineno=6)
# DEBUG - stack ['$phi136.0', '$binop_truediv192.15']
# DEBUG - dispatch pc=198, inst=LOAD_FAST(arg=3, lineno=6)
# DEBUG - stack ['$phi136.0', '$binop_truediv192.15', '$sma196.16']
# DEBUG - dispatch pc=200, inst=LOAD_FAST(arg=1, lineno=6)
# DEBUG - stack ['$phi136.0', '$binop_truediv192.15', '$sma196.16', '$i198.17']
# DEBUG - dispatch pc=202, inst=BINARY_OP(arg=0, lineno=6)
# DEBUG - stack ['$phi136.0', '$binop_truediv192.15', '$sma196.16', '$i198.17', '$period200.18']
# DEBUG - dispatch pc=206, inst=STORE_SUBSCR(arg=None, lineno=6)
# DEBUG - stack ['$phi136.0', '$binop_truediv192.15', '$sma196.16', '$binop_add202.19']
# DEBUG - dispatch pc=210, inst=JUMP_BACKWARD(arg=40, lineno=6)
# DEBUG - stack ['$phi136.0']
# DEBUG - end state. edges=[Edge(pc=132, stack=('$phi136.0',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=132 nstack_initial=1)])
# DEBUG - -------------------------Prune PHIs-------------------------
# DEBUG - Used_phis: defaultdict(<class 'set'>,
#             {State(pc_initial=0 nstack_initial=0): set(),
#              State(pc_initial=132 nstack_initial=1): {'$phi132.0'},
#              State(pc_initial=136 nstack_initial=2): {'$phi136.1'},
#              State(pc_initial=212 nstack_initial=2): set()})
# DEBUG - defmap: {'$phi132.0': State(pc_initial=0 nstack_initial=0),
#  '$phi136.1': State(pc_initial=132 nstack_initial=1),
#  '$phi212.1': State(pc_initial=132 nstack_initial=1)}
# DEBUG - phismap: defaultdict(<class 'set'>,
#             {'$phi132.0': {('$130get_iter.16',
#                             State(pc_initial=0 nstack_initial=0)),
#                            ('$phi136.0',
#                             State(pc_initial=136 nstack_initial=2))},
#              '$phi136.0': {('$phi132.0',
#                             State(pc_initial=132 nstack_initial=1))},
#              '$phi136.1': {('$132for_iter.2',
#                             State(pc_initial=132 nstack_initial=1))},
#              '$phi212.0': {('$phi132.0',
#                             State(pc_initial=132 nstack_initial=1))},
#              '$phi212.1': {('$132for_iter.2',
#                             State(pc_initial=132 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi132.0': {('$130get_iter.16',
#                             State(pc_initial=0 nstack_initial=0)),
#                            ('$phi132.0',
#                             State(pc_initial=132 nstack_initial=1))},
#              '$phi136.0': {('$130get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi136.1': {('$132for_iter.2',
#                             State(pc_initial=132 nstack_initial=1))},
#              '$phi212.0': {('$130get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi212.1': {('$132for_iter.2',
#                             State(pc_initial=132 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi132.0': {('$130get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi136.0': {('$130get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi136.1': {('$132for_iter.2',
#                             State(pc_initial=132 nstack_initial=1))},
#              '$phi212.0': {('$130get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi212.1': {('$132for_iter.2',
#                             State(pc_initial=132 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi132.0': {('$130get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi136.0': {('$130get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi136.1': {('$132for_iter.2',
#                             State(pc_initial=132 nstack_initial=1))},
#              '$phi212.0': {('$130get_iter.16',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi212.1': {('$132for_iter.2',
#                             State(pc_initial=132 nstack_initial=1))}})
# DEBUG - keep phismap: {'$phi132.0': {('$130get_iter.16', State(pc_initial=0 nstack_initial=0))},
#  '$phi136.1': {('$132for_iter.2', State(pc_initial=132 nstack_initial=1))}}
# DEBUG - new_out: defaultdict(<class 'dict'>,
#             {State(pc_initial=0 nstack_initial=0): {'$phi132.0': '$130get_iter.16'},
#              State(pc_initial=132 nstack_initial=1): {'$phi136.1': '$132for_iter.2'}})
# DEBUG - ----------------------DONE Prune PHIs-----------------------
# DEBUG - block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'idx': 0, 'res': '$4load_global.0'}), (14, {'item': '$4load_global.0', 'res': '$14load_attr.2'}), (34, {'res': '$data34.3'}), (36, {'idx': 0, 'res': '$36load_global.4'}), (46, {'item': '$36load_global.4', 'res': '$46load_attr.5'}), (68, {'func': '$14load_attr.2', 'args': ['$data34.3', '$46load_attr.5'], 'kw_names': 1, 'res': '$68call.6'}), (76, {'value': '$68call.6'}), (78, {'idx': 3, 'res': '$78load_global.7'}), (88, {'res': '$sma88.9'}), (90, {'item': '$sma88.9', 'res': '$90load_attr.10'}), (110, {'res': '$const110.11'}), (112, {'index': '$const110.11', 'target': '$90load_attr.10', 'res': '$112binary_subscr.12'}), (116, {'res': '$period116.13'}), (118, {'op': '-', 'lhs': '$112binary_subscr.12', 'rhs': '$period116.13', 'res': '$binop_sub118.14'}), (122, {'func': '$78load_global.7', 'args': ['$binop_sub118.14'], 'kw_names': None, 'res': '$122call.15'}), (130, {'value': '$122call.15', 'res': '$130get_iter.16'})), outgoing_phis={'$phi132.0': '$130get_iter.16'}, blockstack=(), active_try_block=None, outgoing_edgepushed={132: ('$130get_iter.16',)})
# DEBUG - block_infos State(pc_initial=132 nstack_initial=1):
# AdaptBlockInfo(insts=((132, {'iterator': '$phi132.0', 'pair': '$132for_iter.1', 'indval': '$132for_iter.2', 'pred': '$132for_iter.3'}),), outgoing_phis={'$phi136.1': '$132for_iter.2'}, blockstack=(), active_try_block=None, outgoing_edgepushed={212: ('$phi132.0', '$132for_iter.2'), 136: ('$phi132.0', '$132for_iter.2')})
# DEBUG - block_infos State(pc_initial=136 nstack_initial=2):
# AdaptBlockInfo(insts=((136, {'value': '$phi136.1'}), (138, {'idx': 0, 'res': '$138load_global.2'}), (148, {'item': '$138load_global.2', 'res': '$148load_attr.4'}), (168, {'res': '$data168.5'}), (170, {'res': '$i170.6'}), (172, {'res': '$i172.7'}), (174, {'res': '$period174.8'}), (176, {'op': '+', 'lhs': '$i172.7', 'rhs': '$period174.8', 'res': '$binop_add176.9'}), (180, {'start': '$i170.6', 'end': '$binop_add176.9', 'container': '$data168.5', 'res': '$180binary_slice.11', 'slicevar': '$180binary_slice.12', 'temp_res': '$180binary_slice.10'}), (182, {'func': '$148load_attr.4', 'args': ['$180binary_slice.11'], 'kw_names': None, 'res': '$182call.13'}), (190, {'res': '$period190.14'}), (192, {'op': '/', 'lhs': '$182call.13', 'rhs': '$period190.14', 'res': '$binop_truediv192.15'}), (196, {'res': '$sma196.16'}), (198, {'res': '$i198.17'}), (200, {'res': '$period200.18'}), (202, {'op': '+', 'lhs': '$i198.17', 'rhs': '$period200.18', 'res': '$binop_add202.19'}), (206, {'target': '$sma196.16', 'index': '$binop_add202.19', 'value': '$binop_truediv192.15'}), (210, {})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={132: ('$phi136.0',)})
# DEBUG - block_infos State(pc_initial=212 nstack_initial=2):
# AdaptBlockInfo(insts=((214, {'res': '$sma214.2'}), (216, {'retval': '$sma214.2', 'castval': '$216return_value.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG - label 0:
#     data = arg(0, name=data)                 ['data']
#     period = arg(1, name=period)             ['period']
#     $4load_global.0 = global(np: <module 'numpy' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numpy\\__init__.py'>) ['$4load_global.0']
#     $14load_attr.2 = getattr(value=$4load_global.0, attr=zeros_like) ['$14load_attr.2', '$4load_global.0']
#     $36load_global.4 = global(np: <module 'numpy' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numpy\\__init__.py'>) ['$36load_global.4']
#     $46load_attr.5 = getattr(value=$36load_global.4, attr=float64) ['$36load_global.4', '$46load_attr.5']
#     sma = call $14load_attr.2(data, func=$14load_attr.2, args=[Var(data, 355378641.py:1)], kws=[('dtype', Var($46load_attr.5, 355378641.py:3))], vararg=None, varkwarg=None, target=None) ['$14load_attr.2', '$46load_attr.5', 'data', 'sma']
#     $78load_global.7 = global(range: <class 'range'>) ['$78load_global.7']
#     $90load_attr.10 = getattr(value=sma, attr=shape) ['$90load_attr.10', 'sma']
#     $const110.11 = const(int, 0)             ['$const110.11']
#     $112binary_subscr.12 = getitem(value=$90load_attr.10, index=$const110.11, fn=<built-in function getitem>) ['$112binary_subscr.12', '$90load_attr.10', '$const110.11']
#     $binop_sub118.14 = $112binary_subscr.12 - period ['$112binary_subscr.12', '$binop_sub118.14', 'period']
#     $122call.15 = call $78load_global.7($binop_sub118.14, func=$78load_global.7, args=[Var($binop_sub118.14, 355378641.py:5)], kws=(), vararg=None, varkwarg=None, target=None) ['$122call.15', '$78load_global.7', '$binop_sub118.14']
#     $130get_iter.16 = getiter(value=$122call.15) ['$122call.15', '$130get_iter.16']
#     $phi132.0 = $130get_iter.16              ['$130get_iter.16', '$phi132.0']
#     jump 132                                 []
# label 132:
#     $132for_iter.1 = iternext(value=$phi132.0) ['$132for_iter.1', '$phi132.0']
#     $132for_iter.2 = pair_first(value=$132for_iter.1) ['$132for_iter.1', '$132for_iter.2']
#     $132for_iter.3 = pair_second(value=$132for_iter.1) ['$132for_iter.1', '$132for_iter.3']
#     $phi136.1 = $132for_iter.2               ['$132for_iter.2', '$phi136.1']
#     branch $132for_iter.3, 136, 212          ['$132for_iter.3']
# label 136:
#     i = $phi136.1                            ['$phi136.1', 'i']
#     $138load_global.2 = global(np: <module 'numpy' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numpy\\__init__.py'>) ['$138load_global.2']
#     $148load_attr.4 = getattr(value=$138load_global.2, attr=sum) ['$138load_global.2', '$148load_attr.4']
#     $binop_add176.9 = i + period             ['$binop_add176.9', 'i', 'period']
#     $180binary_slice.12 = global(slice: <class 'slice'>) ['$180binary_slice.12']
#     $180binary_slice.10 = call $180binary_slice.12(i, $binop_add176.9, func=$180binary_slice.12, args=(Var(i, 355378641.py:5), Var($binop_add176.9, 355378641.py:6)), kws=(), vararg=None, varkwarg=None, target=None) ['$180binary_slice.10', '$180binary_slice.12', '$binop_add176.9', 'i']
#     $180binary_slice.11 = getitem(value=data, index=$180binary_slice.10, fn=<built-in function getitem>) ['$180binary_slice.10', '$180binary_slice.11', 'data']
#     $182call.13 = call $148load_attr.4($180binary_slice.11, func=$148load_attr.4, args=[Var($180binary_slice.11, 355378641.py:6)], kws=(), vararg=None, varkwarg=None, target=None) ['$148load_attr.4', '$180binary_slice.11', '$182call.13']
#     $binop_truediv192.15 = $182call.13 / period ['$182call.13', '$binop_truediv192.15', 'period']
#     $binop_add202.19 = i + period            ['$binop_add202.19', 'i', 'period']
#     sma[$binop_add202.19] = $binop_truediv192.15 ['$binop_add202.19', '$binop_truediv192.15', 'sma']
#     jump 132                                 []
# label 212:
#     $216return_value.3 = cast(value=sma)     ['$216return_value.3', 'sma']
#     return $216return_value.3                ['$216return_value.3']
#
# DEBUG - ==== SSA block analysis pass on 0
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2852E40>
# DEBUG - on stmt: data = arg(0, name=data)
# DEBUG - on stmt: period = arg(1, name=period)
# DEBUG - on stmt: $4load_global.0 = global(np: <module 'numpy' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numpy\\__init__.py'>)
# DEBUG - on stmt: $14load_attr.2 = getattr(value=$4load_global.0, attr=zeros_like)
# DEBUG - on stmt: $36load_global.4 = global(np: <module 'numpy' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numpy\\__init__.py'>)
# DEBUG - on stmt: $46load_attr.5 = getattr(value=$36load_global.4, attr=float64)
# DEBUG - on stmt: sma = call $14load_attr.2(data, func=$14load_attr.2, args=[Var(data, 355378641.py:1)], kws=[('dtype', Var($46load_attr.5, 355378641.py:3))], vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: $78load_global.7 = global(range: <class 'range'>)
# DEBUG - on stmt: $90load_attr.10 = getattr(value=sma, attr=shape)
# DEBUG - on stmt: $const110.11 = const(int, 0)
# DEBUG - on stmt: $112binary_subscr.12 = static_getitem(value=$90load_attr.10, index=0, index_var=$const110.11, fn=<built-in function getitem>)
# DEBUG - on stmt: $binop_sub118.14 = $112binary_subscr.12 - period
# DEBUG - on stmt: $122call.15 = call $78load_global.7($binop_sub118.14, func=$78load_global.7, args=[Var($binop_sub118.14, 355378641.py:5)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: $130get_iter.16 = getiter(value=$122call.15)
# DEBUG - on stmt: $phi132.0 = $130get_iter.16
# DEBUG - on stmt: jump 132
# DEBUG - ==== SSA block analysis pass on 132
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2852E40>
# DEBUG - on stmt: $132for_iter.1 = iternext(value=$phi132.0)
# DEBUG - on stmt: $132for_iter.2 = pair_first(value=$132for_iter.1)
# DEBUG - on stmt: $132for_iter.3 = pair_second(value=$132for_iter.1)
# DEBUG - on stmt: $phi136.1 = $132for_iter.2
# DEBUG - on stmt: branch $132for_iter.3, 136, 212
# DEBUG - ==== SSA block analysis pass on 136
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2852E40>
# DEBUG - on stmt: i = $phi136.1
# DEBUG - on stmt: $138load_global.2 = global(np: <module 'numpy' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numpy\\__init__.py'>)
# DEBUG - on stmt: $148load_attr.4 = getattr(value=$138load_global.2, attr=sum)
# DEBUG - on stmt: $binop_add176.9 = i + period
# DEBUG - on stmt: $180binary_slice.12 = global(slice: <class 'slice'>)
# DEBUG - on stmt: $180binary_slice.10 = call $180binary_slice.12(i, $binop_add176.9, func=$180binary_slice.12, args=(Var(i, 355378641.py:5), Var($binop_add176.9, 355378641.py:6)), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: $180binary_slice.11 = getitem(value=data, index=$180binary_slice.10, fn=<built-in function getitem>)
# DEBUG - on stmt: $182call.13 = call $148load_attr.4($180binary_slice.11, func=$148load_attr.4, args=[Var($180binary_slice.11, 355378641.py:6)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: $binop_truediv192.15 = $182call.13 / period
# DEBUG - on stmt: $binop_add202.19 = i + period
# DEBUG - on stmt: sma[$binop_add202.19] = $binop_truediv192.15
# DEBUG - on stmt: jump 132
# DEBUG - ==== SSA block analysis pass on 212
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2852E40>
# DEBUG - on stmt: $216return_value.3 = cast(value=sma)
# DEBUG - on stmt: return $216return_value.3
# DEBUG - defs defaultdict(<class 'list'>,
#             {'$112binary_subscr.12': [(<numba.core.ir.Assign object at 0x00000169D28394C0>,
#                                        0)],
#              '$122call.15': [(<numba.core.ir.Assign object at 0x00000169D2850B90>,
#                               0)],
#              '$130get_iter.16': [(<numba.core.ir.Assign object at 0x00000169D2850BF0>,
#                                   0)],
#              '$132for_iter.1': [(<numba.core.ir.Assign object at 0x00000169D2850CB0>,
#                                  132)],
#              '$132for_iter.2': [(<numba.core.ir.Assign object at 0x00000169D2850D40>,
#                                  132)],
#              '$132for_iter.3': [(<numba.core.ir.Assign object at 0x00000169D2850DD0>,
#                                  132)],
#              '$138load_global.2': [(<numba.core.ir.Assign object at 0x00000169D2850F80>,
#                                     136)],
#              '$148load_attr.4': [(<numba.core.ir.Assign object at 0x00000169D28510A0>,
#                                   136)],
#              '$14load_attr.2': [(<numba.core.ir.Assign object at 0x00000169D28393A0>,
#                                  0)],
#              '$180binary_slice.10': [(<numba.core.ir.Assign object at 0x00000169D2851790>,
#                                       136)],
#              '$180binary_slice.11': [(<numba.core.ir.Assign object at 0x00000169D2851880>,
#                                       136)],
#              '$180binary_slice.12': [(<numba.core.ir.Assign object at 0x00000169D28516A0>,
#                                       136)],
#              '$182call.13': [(<numba.core.ir.Assign object at 0x00000169D2851A00>,
#                               136)],
#              '$216return_value.3': [(<numba.core.ir.Assign object at 0x00000169D2851D00>,
#                                      212)],
#              '$36load_global.4': [(<numba.core.ir.Assign object at 0x00000169D28501A0>,
#                                    0)],
#              '$46load_attr.5': [(<numba.core.ir.Assign object at 0x00000169D2850440>,
#                                  0)],
#              '$4load_global.0': [(<numba.core.ir.Assign object at 0x00000169D28391C0>,
#                                   0)],
#              '$78load_global.7': [(<numba.core.ir.Assign object at 0x00000169D2850650>,
#                                    0)],
#              '$90load_attr.10': [(<numba.core.ir.Assign object at 0x00000169D28507A0>,
#                                   0)],
#              '$binop_add176.9': [(<numba.core.ir.Assign object at 0x00000169D28515B0>,
#                                   136)],
#              '$binop_add202.19': [(<numba.core.ir.Assign object at 0x00000169D2852000>,
#                                    136)],
#              '$binop_sub118.14': [(<numba.core.ir.Assign object at 0x00000169D2850AA0>,
#                                    0)],
#              '$binop_truediv192.15': [(<numba.core.ir.Assign object at 0x00000169D2851C10>,
#                                        136)],
#              '$const110.11': [(<numba.core.ir.Assign object at 0x00000169D2850860>,
#                                0)],
#              '$phi132.0': [(<numba.core.ir.Assign object at 0x00000169D28387A0>,
#                             0)],
#              '$phi136.1': [(<numba.core.ir.Assign object at 0x00000169D2839C70>,
#                             132)],
#              'data': [(<numba.core.ir.Assign object at 0x00000169D2813CB0>, 0)],
#              'i': [(<numba.core.ir.Assign object at 0x00000169D2850E90>, 136)],
#              'period': [(<numba.core.ir.Assign object at 0x00000169D2838B90>,
#                          0)],
#              'sma': [(<numba.core.ir.Assign object at 0x00000169D2850530>, 0)]})
# DEBUG - SSA violators <numba.core.utils.OrderedSet object at 0x00000169D2813800>
# DEBUG - bytecode dump:
# >          0	NOP(arg=None, lineno=4468)
#            2	RESUME(arg=0, lineno=4468)
#            4	LOAD_GLOBAL(arg=1, lineno=4469)
#           14	LOAD_ATTR(arg=2, lineno=4469)
#           34	LOAD_FAST(arg=0, lineno=4469)
#           36	LOAD_FAST(arg=1, lineno=4469)
#           38	KW_NAMES(arg=1, lineno=4469)
#           40	CALL(arg=2, lineno=4469)
#           48	STORE_FAST(arg=2, lineno=4469)
#           50	LOAD_FAST(arg=2, lineno=4470)
#           52	LOAD_ATTR(arg=5, lineno=4470)
#           72	CALL(arg=0, lineno=4470)
#           80	POP_TOP(arg=None, lineno=4470)
#           82	LOAD_FAST(arg=2, lineno=4471)
#           84	RETURN_VALUE(arg=None, lineno=4471)
# DEBUG - pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG - stack: []
# DEBUG - state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG - dispatch pc=0, inst=NOP(arg=None, lineno=4468)
# DEBUG - stack []
# DEBUG - dispatch pc=2, inst=RESUME(arg=0, lineno=4468)
# DEBUG - stack []
# DEBUG - dispatch pc=4, inst=LOAD_GLOBAL(arg=1, lineno=4469)
# DEBUG - stack []
# DEBUG - dispatch pc=14, inst=LOAD_ATTR(arg=2, lineno=4469)
# DEBUG - stack ['$null$4.1', '$4load_global.0']
# DEBUG - dispatch pc=34, inst=LOAD_FAST(arg=0, lineno=4469)
# DEBUG - stack ['$null$4.1', '$14load_attr.2']
# DEBUG - dispatch pc=36, inst=LOAD_FAST(arg=1, lineno=4469)
# DEBUG - stack ['$null$4.1', '$14load_attr.2', '$a34.3']
# DEBUG - dispatch pc=38, inst=KW_NAMES(arg=1, lineno=4469)
# DEBUG - stack ['$null$4.1', '$14load_attr.2', '$a34.3', '$dtype36.4']
# DEBUG - dispatch pc=40, inst=CALL(arg=2, lineno=4469)
# DEBUG - stack ['$null$4.1', '$14load_attr.2', '$a34.3', '$dtype36.4']
# DEBUG - dispatch pc=48, inst=STORE_FAST(arg=2, lineno=4469)
# DEBUG - stack ['$40call.5']
# DEBUG - dispatch pc=50, inst=LOAD_FAST(arg=2, lineno=4470)
# DEBUG - stack []
# DEBUG - dispatch pc=52, inst=LOAD_ATTR(arg=5, lineno=4470)
# DEBUG - stack ['$arr50.6']
# DEBUG - dispatch pc=72, inst=CALL(arg=0, lineno=4470)
# DEBUG - stack ['$null$52.7', '$52load_attr.8']
# DEBUG - dispatch pc=80, inst=POP_TOP(arg=None, lineno=4470)
# DEBUG - stack ['$72call.9']
# DEBUG - dispatch pc=82, inst=LOAD_FAST(arg=2, lineno=4471)
# DEBUG - stack []
# DEBUG - dispatch pc=84, inst=RETURN_VALUE(arg=None, lineno=4471)
# DEBUG - stack ['$arr82.10']
# DEBUG - end state. edges=[]
# DEBUG - -------------------------Prune PHIs-------------------------
# DEBUG - Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG - defmap: {}
# DEBUG - phismap: defaultdict(<class 'set'>, {})
# DEBUG - changing phismap: defaultdict(<class 'set'>, {})
# DEBUG - keep phismap: {}
# DEBUG - new_out: defaultdict(<class 'dict'>, {})
# DEBUG - ----------------------DONE Prune PHIs-----------------------
# DEBUG - block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'idx': 0, 'res': '$4load_global.0'}), (14, {'item': '$4load_global.0', 'res': '$14load_attr.2'}), (34, {'res': '$a34.3'}), (36, {'res': '$dtype36.4'}), (40, {'func': '$14load_attr.2', 'args': ['$a34.3', '$dtype36.4'], 'kw_names': 1, 'res': '$40call.5'}), (48, {'value': '$40call.5'}), (50, {'res': '$arr50.6'}), (52, {'item': '$arr50.6', 'res': '$52load_attr.8'}), (72, {'func': '$52load_attr.8', 'args': [], 'kw_names': None, 'res': '$72call.9'}), (82, {'res': '$arr82.10'}), (84, {'retval': '$arr82.10', 'castval': '$84return_value.11'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG - label 0:
#     a = arg(0, name=a)                       ['a']
#     dtype = arg(1, name=dtype)               ['dtype']
#     $4load_global.0 = global(np: <module 'numpy' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numpy\\__init__.py'>) ['$4load_global.0']
#     $14load_attr.2 = getattr(value=$4load_global.0, attr=empty_like) ['$14load_attr.2', '$4load_global.0']
#     arr = call $14load_attr.2(a, func=$14load_attr.2, args=[Var(a, arrayobj.py:4468)], kws=[('dtype', Var(dtype, arrayobj.py:4468))], vararg=None, varkwarg=None, target=None) ['$14load_attr.2', 'a', 'arr', 'dtype']
#     $52load_attr.8 = getattr(value=arr, attr=_zero_fill) ['$52load_attr.8', 'arr']
#     $72call.9 = call $52load_attr.8(func=$52load_attr.8, args=[], kws=(), vararg=None, varkwarg=None, target=None) ['$52load_attr.8', '$72call.9']
#     $84return_value.11 = cast(value=arr)     ['$84return_value.11', 'arr']
#     return $84return_value.11                ['$84return_value.11']
#
# DEBUG - ==== SSA block analysis pass on 0
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D28C69C0>
# DEBUG - on stmt: a = arg(0, name=a)
# DEBUG - on stmt: dtype = arg(1, name=dtype)
# DEBUG - on stmt: $4load_global.0 = global(np: <module 'numpy' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numpy\\__init__.py'>)
# DEBUG - on stmt: $14load_attr.2 = getattr(value=$4load_global.0, attr=empty_like)
# DEBUG - on stmt: arr = call $14load_attr.2(a, func=$14load_attr.2, args=[Var(a, arrayobj.py:4468)], kws=[('dtype', Var(dtype, arrayobj.py:4468))], vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: $52load_attr.8 = getattr(value=arr, attr=_zero_fill)
# DEBUG - on stmt: $72call.9 = call $52load_attr.8(func=$52load_attr.8, args=[], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: $84return_value.11 = cast(value=arr)
# DEBUG - on stmt: return $84return_value.11
# DEBUG - defs defaultdict(<class 'list'>,
#             {'$14load_attr.2': [(<numba.core.ir.Assign object at 0x00000169D28C4B90>,
#                                  0)],
#              '$4load_global.0': [(<numba.core.ir.Assign object at 0x00000169D28C4A70>,
#                                   0)],
#              '$52load_attr.8': [(<numba.core.ir.Assign object at 0x00000169D28C51C0>,
#                                  0)],
#              '$72call.9': [(<numba.core.ir.Assign object at 0x00000169D28C5340>,
#                             0)],
#              '$84return_value.11': [(<numba.core.ir.Assign object at 0x00000169D28C5550>,
#                                      0)],
#              'a': [(<numba.core.ir.Assign object at 0x00000169D28C4830>, 0)],
#              'arr': [(<numba.core.ir.Assign object at 0x00000169D28C4EF0>, 0)],
#              'dtype': [(<numba.core.ir.Assign object at 0x00000169D28C4920>,
#                         0)]})
# DEBUG - SSA violators <numba.core.utils.OrderedSet object at 0x00000169D28A5DF0>
# DEBUG - bytecode dump:
# >          0	NOP(arg=None, lineno=4428)
#            2	COPY_FREE_VARS(arg=1, lineno=4428)
#            4	RESUME(arg=0, lineno=4428)
#            6	LOAD_GLOBAL(arg=1, lineno=4429)
#           16	LOAD_FAST(arg=0, lineno=4429)
#           18	LOAD_FAST(arg=1, lineno=4429)
#           20	LOAD_DEREF(arg=2, lineno=4429)
#           22	CALL(arg=3, lineno=4429)
#           30	RETURN_VALUE(arg=None, lineno=4429)
# DEBUG - pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG - stack: []
# DEBUG - state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG - dispatch pc=0, inst=NOP(arg=None, lineno=4428)
# DEBUG - stack []
# DEBUG - dispatch pc=2, inst=COPY_FREE_VARS(arg=1, lineno=4428)
# DEBUG - stack []
# DEBUG - dispatch pc=4, inst=RESUME(arg=0, lineno=4428)
# DEBUG - stack []
# DEBUG - dispatch pc=6, inst=LOAD_GLOBAL(arg=1, lineno=4429)
# DEBUG - stack []
# DEBUG - dispatch pc=16, inst=LOAD_FAST(arg=0, lineno=4429)
# DEBUG - stack ['$null$6.1', '$6load_global.0']
# DEBUG - dispatch pc=18, inst=LOAD_FAST(arg=1, lineno=4429)
# DEBUG - stack ['$null$6.1', '$6load_global.0', '$arr16.2']
# DEBUG - dispatch pc=20, inst=LOAD_DEREF(arg=2, lineno=4429)
# DEBUG - stack ['$null$6.1', '$6load_global.0', '$arr16.2', '$dtype18.3']
# DEBUG - dispatch pc=22, inst=CALL(arg=3, lineno=4429)
# DEBUG - stack ['$null$6.1', '$6load_global.0', '$arr16.2', '$dtype18.3', '$20load_deref.4']
# DEBUG - dispatch pc=30, inst=RETURN_VALUE(arg=None, lineno=4429)
# DEBUG - stack ['$22call.5']
# DEBUG - end state. edges=[]
# DEBUG - -------------------------Prune PHIs-------------------------
# DEBUG - Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG - defmap: {}
# DEBUG - phismap: defaultdict(<class 'set'>, {})
# DEBUG - changing phismap: defaultdict(<class 'set'>, {})
# DEBUG - keep phismap: {}
# DEBUG - new_out: defaultdict(<class 'dict'>, {})
# DEBUG - ----------------------DONE Prune PHIs-----------------------
# DEBUG - block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {}), (6, {'idx': 0, 'res': '$6load_global.0'}), (16, {'res': '$arr16.2'}), (18, {'res': '$dtype18.3'}), (20, {'res': '$20load_deref.4'}), (22, {'func': '$6load_global.0', 'args': ['$arr16.2', '$dtype18.3', '$20load_deref.4'], 'kw_names': None, 'res': '$22call.5'}), (30, {'retval': '$22call.5', 'castval': '$30return_value.6'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG - label 0:
#     arr = arg(0, name=arr)                   ['arr']
#     dtype = arg(1, name=dtype)               ['dtype']
#     $6load_global.0 = global(numpy_empty_like_nd: <intrinsic numpy_empty_like_nd>) ['$6load_global.0']
#     $20load_deref.4 = freevar(retty: array(float64, 1d, C)) ['$20load_deref.4']
#     $22call.5 = call $6load_global.0(arr, dtype, $20load_deref.4, func=$6load_global.0, args=[Var(arr, arrayobj.py:4428), Var(dtype, arrayobj.py:4428), Var($20load_deref.4, arrayobj.py:4429)], kws=(), vararg=None, varkwarg=None, target=None) ['$20load_deref.4', '$22call.5', '$6load_global.0', 'arr', 'dtype']
#     $30return_value.6 = cast(value=$22call.5) ['$22call.5', '$30return_value.6']
#     return $30return_value.6                 ['$30return_value.6']
#
# DEBUG - ==== SSA block analysis pass on 0
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D28C7EF0>
# DEBUG - on stmt: arr = arg(0, name=arr)
# DEBUG - on stmt: dtype = arg(1, name=dtype)
# DEBUG - on stmt: $6load_global.0 = global(numpy_empty_like_nd: <intrinsic numpy_empty_like_nd>)
# DEBUG - on stmt: $20load_deref.4 = freevar(retty: array(float64, 1d, C))
# DEBUG - on stmt: $22call.5 = call $6load_global.0(arr, dtype, $20load_deref.4, func=$6load_global.0, args=[Var(arr, arrayobj.py:4428), Var(dtype, arrayobj.py:4428), Var($20load_deref.4, arrayobj.py:4429)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: $30return_value.6 = cast(value=$22call.5)
# DEBUG - on stmt: return $30return_value.6
# DEBUG - defs defaultdict(<class 'list'>,
#             {'$20load_deref.4': [(<numba.core.ir.Assign object at 0x00000169D2962330>,
#                                   0)],
#              '$22call.5': [(<numba.core.ir.Assign object at 0x00000169D2962480>,
#                             0)],
#              '$30return_value.6': [(<numba.core.ir.Assign object at 0x00000169D2962570>,
#                                     0)],
#              '$6load_global.0': [(<numba.core.ir.Assign object at 0x00000169D2962060>,
#                                   0)],
#              'arr': [(<numba.core.ir.Assign object at 0x00000169D2961E20>, 0)],
#              'dtype': [(<numba.core.ir.Assign object at 0x00000169D2961F10>,
#                         0)]})
# DEBUG - SSA violators <numba.core.utils.OrderedSet object at 0x00000169D28C7EF0>
# DEBUG - bytecode dump:
# >          0	NOP(arg=None, lineno=4264)
#            2	RESUME(arg=0, lineno=4264)
#            4	LOAD_FAST(arg=0, lineno=4267)
#            6	LOAD_ATTR(arg=1, lineno=4267)
#           26	LOAD_FAST(arg=1, lineno=4267)
#           28	LOAD_FAST(arg=2, lineno=4267)
#           30	CALL(arg=2, lineno=4267)
#           38	RETURN_VALUE(arg=None, lineno=4267)
# DEBUG - pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG - stack: []
# DEBUG - state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG - dispatch pc=0, inst=NOP(arg=None, lineno=4264)
# DEBUG - stack []
# DEBUG - dispatch pc=2, inst=RESUME(arg=0, lineno=4264)
# DEBUG - stack []
# DEBUG - dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=4267)
# DEBUG - stack []
# DEBUG - dispatch pc=6, inst=LOAD_ATTR(arg=1, lineno=4267)
# DEBUG - stack ['$arrtype4.0']
# DEBUG - dispatch pc=26, inst=LOAD_FAST(arg=1, lineno=4267)
# DEBUG - stack ['$null$6.1', '$6load_attr.2']
# DEBUG - dispatch pc=28, inst=LOAD_FAST(arg=2, lineno=4267)
# DEBUG - stack ['$null$6.1', '$6load_attr.2', '$size26.3']
# DEBUG - dispatch pc=30, inst=CALL(arg=2, lineno=4267)
# DEBUG - stack ['$null$6.1', '$6load_attr.2', '$size26.3', '$align28.4']
# DEBUG - dispatch pc=38, inst=RETURN_VALUE(arg=None, lineno=4267)
# DEBUG - stack ['$30call.5']
# DEBUG - end state. edges=[]
# DEBUG - -------------------------Prune PHIs-------------------------
# DEBUG - Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG - defmap: {}
# DEBUG - phismap: defaultdict(<class 'set'>, {})
# DEBUG - changing phismap: defaultdict(<class 'set'>, {})
# DEBUG - keep phismap: {}
# DEBUG - new_out: defaultdict(<class 'dict'>, {})
# DEBUG - ----------------------DONE Prune PHIs-----------------------
# DEBUG - block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'res': '$arrtype4.0'}), (6, {'item': '$arrtype4.0', 'res': '$6load_attr.2'}), (26, {'res': '$size26.3'}), (28, {'res': '$align28.4'}), (30, {'func': '$6load_attr.2', 'args': ['$size26.3', '$align28.4'], 'kw_names': None, 'res': '$30call.5'}), (38, {'retval': '$30call.5', 'castval': '$38return_value.6'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG - label 0:
#     arrtype = arg(0, name=arrtype)           ['arrtype']
#     size = arg(1, name=size)                 ['size']
#     align = arg(2, name=align)               ['align']
#     $6load_attr.2 = getattr(value=arrtype, attr=_allocate) ['$6load_attr.2', 'arrtype']
#     $30call.5 = call $6load_attr.2(size, align, func=$6load_attr.2, args=[Var(size, arrayobj.py:4264), Var(align, arrayobj.py:4264)], kws=(), vararg=None, varkwarg=None, target=None) ['$30call.5', '$6load_attr.2', 'align', 'size']
#     $38return_value.6 = cast(value=$30call.5) ['$30call.5', '$38return_value.6']
#     return $38return_value.6                 ['$38return_value.6']
#
# DEBUG - ==== SSA block analysis pass on 0
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D29B38F0>
# DEBUG - on stmt: arrtype = arg(0, name=arrtype)
# DEBUG - on stmt: size = arg(1, name=size)
# DEBUG - on stmt: align = arg(2, name=align)
# DEBUG - on stmt: $6load_attr.2 = getattr(value=arrtype, attr=_allocate)
# DEBUG - on stmt: $30call.5 = call $6load_attr.2(size, align, func=$6load_attr.2, args=[Var(size, arrayobj.py:4264), Var(align, arrayobj.py:4264)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: $38return_value.6 = cast(value=$30call.5)
# DEBUG - on stmt: return $38return_value.6
# DEBUG - defs defaultdict(<class 'list'>,
#             {'$30call.5': [(<numba.core.ir.Assign object at 0x00000169D29B2720>,
#                             0)],
#              '$38return_value.6': [(<numba.core.ir.Assign object at 0x00000169D29B2810>,
#                                     0)],
#              '$6load_attr.2': [(<numba.core.ir.Assign object at 0x00000169D29B23C0>,
#                                 0)],
#              'align': [(<numba.core.ir.Assign object at 0x00000169D29B2180>,
#                         0)],
#              'arrtype': [(<numba.core.ir.Assign object at 0x00000169D29B1FA0>,
#                           0)],
#              'size': [(<numba.core.ir.Assign object at 0x00000169D29B2090>,
#                        0)]})
# DEBUG - SSA violators <numba.core.utils.OrderedSet object at 0x00000169D28537A0>
# DEBUG - bytecode dump:
# >          0	NOP(arg=None, lineno=4259)
#            2	RESUME(arg=0, lineno=4259)
#            4	LOAD_GLOBAL(arg=1, lineno=4260)
#           14	LOAD_FAST(arg=1, lineno=4260)
#           16	LOAD_FAST(arg=2, lineno=4260)
#           18	CALL(arg=2, lineno=4260)
#           26	RETURN_VALUE(arg=None, lineno=4260)
# DEBUG - pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG - stack: []
# DEBUG - state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG - dispatch pc=0, inst=NOP(arg=None, lineno=4259)
# DEBUG - stack []
# DEBUG - dispatch pc=2, inst=RESUME(arg=0, lineno=4259)
# DEBUG - stack []
# DEBUG - dispatch pc=4, inst=LOAD_GLOBAL(arg=1, lineno=4260)
# DEBUG - stack []
# DEBUG - dispatch pc=14, inst=LOAD_FAST(arg=1, lineno=4260)
# DEBUG - stack ['$null$4.1', '$4load_global.0']
# DEBUG - dispatch pc=16, inst=LOAD_FAST(arg=2, lineno=4260)
# DEBUG - stack ['$null$4.1', '$4load_global.0', '$allocsize14.2']
# DEBUG - dispatch pc=18, inst=CALL(arg=2, lineno=4260)
# DEBUG - stack ['$null$4.1', '$4load_global.0', '$allocsize14.2', '$align16.3']
# DEBUG - dispatch pc=26, inst=RETURN_VALUE(arg=None, lineno=4260)
# DEBUG - stack ['$18call.4']
# DEBUG - end state. edges=[]
# DEBUG - -------------------------Prune PHIs-------------------------
# DEBUG - Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG - defmap: {}
# DEBUG - phismap: defaultdict(<class 'set'>, {})
# DEBUG - changing phismap: defaultdict(<class 'set'>, {})
# DEBUG - keep phismap: {}
# DEBUG - new_out: defaultdict(<class 'dict'>, {})
# DEBUG - ----------------------DONE Prune PHIs-----------------------
# DEBUG - block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'idx': 0, 'res': '$4load_global.0'}), (14, {'res': '$allocsize14.2'}), (16, {'res': '$align16.3'}), (18, {'func': '$4load_global.0', 'args': ['$allocsize14.2', '$align16.3'], 'kw_names': None, 'res': '$18call.4'}), (26, {'retval': '$18call.4', 'castval': '$26return_value.5'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG - label 0:
#     cls = arg(0, name=cls)                   ['cls']
#     allocsize = arg(1, name=allocsize)       ['allocsize']
#     align = arg(2, name=align)               ['align']
#     $4load_global.0 = global(intrin_alloc: <intrinsic intrin_alloc>) ['$4load_global.0']
#     $18call.4 = call $4load_global.0(allocsize, align, func=$4load_global.0, args=[Var(allocsize, arrayobj.py:4259), Var(align, arrayobj.py:4259)], kws=(), vararg=None, varkwarg=None, target=None) ['$18call.4', '$4load_global.0', 'align', 'allocsize']
#     $26return_value.5 = cast(value=$18call.4) ['$18call.4', '$26return_value.5']
#     return $26return_value.5                 ['$26return_value.5']
#
# DEBUG - ==== SSA block analysis pass on 0
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D29C6DE0>
# DEBUG - on stmt: cls = arg(0, name=cls)
# DEBUG - on stmt: allocsize = arg(1, name=allocsize)
# DEBUG - on stmt: align = arg(2, name=align)
# DEBUG - on stmt: $4load_global.0 = global(intrin_alloc: <intrinsic intrin_alloc>)
# DEBUG - on stmt: $18call.4 = call $4load_global.0(allocsize, align, func=$4load_global.0, args=[Var(allocsize, arrayobj.py:4259), Var(align, arrayobj.py:4259)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: $26return_value.5 = cast(value=$18call.4)
# DEBUG - on stmt: return $26return_value.5
# DEBUG - defs defaultdict(<class 'list'>,
#             {'$18call.4': [(<numba.core.ir.Assign object at 0x00000169D29C6F00>,
#                             0)],
#              '$26return_value.5': [(<numba.core.ir.Assign object at 0x00000169D29C7020>,
#                                     0)],
#              '$4load_global.0': [(<numba.core.ir.Assign object at 0x00000169D29C6B70>,
#                                   0)],
#              'align': [(<numba.core.ir.Assign object at 0x00000169D29C6A20>,
#                         0)],
#              'allocsize': [(<numba.core.ir.Assign object at 0x00000169D29C6930>,
#                             0)],
#              'cls': [(<numba.core.ir.Assign object at 0x00000169D29C6840>, 0)]})
# DEBUG - SSA violators <numba.core.utils.OrderedSet object at 0x00000169D28A79B0>
# DEBUG - bytecode dump:
# >          0	NOP(arg=None, lineno=4447)
#            2	RESUME(arg=0, lineno=4447)
#            4	LOAD_GLOBAL(arg=1, lineno=4448)
#           14	LOAD_FAST(arg=0, lineno=4448)
#           16	CALL(arg=1, lineno=4448)
#           24	POP_TOP(arg=None, lineno=4448)
#           26	RETURN_CONST(arg=0, lineno=4448)
# DEBUG - pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG - stack: []
# DEBUG - state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG - dispatch pc=0, inst=NOP(arg=None, lineno=4447)
# DEBUG - stack []
# DEBUG - dispatch pc=2, inst=RESUME(arg=0, lineno=4447)
# DEBUG - stack []
# DEBUG - dispatch pc=4, inst=LOAD_GLOBAL(arg=1, lineno=4448)
# DEBUG - stack []
# DEBUG - dispatch pc=14, inst=LOAD_FAST(arg=0, lineno=4448)
# DEBUG - stack ['$null$4.1', '$4load_global.0']
# DEBUG - dispatch pc=16, inst=CALL(arg=1, lineno=4448)
# DEBUG - stack ['$null$4.1', '$4load_global.0', '$self14.2']
# DEBUG - dispatch pc=24, inst=POP_TOP(arg=None, lineno=4448)
# DEBUG - stack ['$16call.3']
# DEBUG - dispatch pc=26, inst=RETURN_CONST(arg=0, lineno=4448)
# DEBUG - stack []
# DEBUG - end state. edges=[]
# DEBUG - -------------------------Prune PHIs-------------------------
# DEBUG - Used_phis: defaultdict(<class 'set'>, {State(pc_initial=0 nstack_initial=0): set()})
# DEBUG - defmap: {}
# DEBUG - phismap: defaultdict(<class 'set'>, {})
# DEBUG - changing phismap: defaultdict(<class 'set'>, {})
# DEBUG - keep phismap: {}
# DEBUG - new_out: defaultdict(<class 'dict'>, {})
# DEBUG - ----------------------DONE Prune PHIs-----------------------
# DEBUG - block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'idx': 0, 'res': '$4load_global.0'}), (14, {'res': '$self14.2'}), (16, {'func': '$4load_global.0', 'args': ['$self14.2'], 'kw_names': None, 'res': '$16call.3'}), (26, {'retval': '$const26.4', 'castval': '$26return_const.5'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG - label 0:
#     self = arg(0, name=self)                 ['self']
#     $4load_global.0 = global(_zero_fill_array_method: <intrinsic _zero_fill_array_method>) ['$4load_global.0']
#     $16call.3 = call $4load_global.0(self, func=$4load_global.0, args=[Var(self, arrayobj.py:4447)], kws=(), vararg=None, varkwarg=None, target=None) ['$16call.3', '$4load_global.0', 'self']
#     $const26.4 = const(NoneType, None)       ['$const26.4']
#     $26return_const.5 = cast(value=$const26.4) ['$26return_const.5', '$const26.4']
#     return $26return_const.5                 ['$26return_const.5']
#
# DEBUG - ==== SSA block analysis pass on 0
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2A72630>
# DEBUG - on stmt: self = arg(0, name=self)
# ...
#                           ('$phi106.0',
#                            State(pc_initial=106 nstack_initial=1))},
#              '$phi52.0': {('$phi48.0', State(pc_initial=48 nstack_initial=1))},
#              '$phi52.1': {('$48for_iter.2',
#                            State(pc_initial=48 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi106.0': {('$phi48.0', State(pc_initial=48 nstack_initial=1))},
#              '$phi108.0': {('$phi48.0', State(pc_initial=48 nstack_initial=1))},
#              '$phi130.0': {('$46get_iter.8',
#                             State(pc_initial=0 nstack_initial=0)),
#                            ('$phi106.0',
#                             State(pc_initial=106 nstack_initial=1))},
#              '$phi130.1': {('$48for_iter.2',
#                             State(pc_initial=48 nstack_initial=1))},
#              '$phi48.0': {('$46get_iter.8',
#                            State(pc_initial=0 nstack_initial=0)),
#                           ('$phi48.0', State(pc_initial=48 nstack_initial=1))},
#              '$phi52.0': {('$46get_iter.8',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi52.1': {('$48for_iter.2',
#                            State(pc_initial=48 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi106.0': {('$46get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi108.0': {('$46get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi130.0': {('$46get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi130.1': {('$48for_iter.2',
#                             State(pc_initial=48 nstack_initial=1))},
#              '$phi48.0': {('$46get_iter.8',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi52.0': {('$46get_iter.8',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi52.1': {('$48for_iter.2',
#                            State(pc_initial=48 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi106.0': {('$46get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi108.0': {('$46get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi130.0': {('$46get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi130.1': {('$48for_iter.2',
#                             State(pc_initial=48 nstack_initial=1))},
#              '$phi48.0': {('$46get_iter.8',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi52.0': {('$46get_iter.8',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi52.1': {('$48for_iter.2',
#                            State(pc_initial=48 nstack_initial=1))}})
# DEBUG - keep phismap: {'$phi48.0': {('$46get_iter.8', State(pc_initial=0 nstack_initial=0))},
#  '$phi52.1': {('$48for_iter.2', State(pc_initial=48 nstack_initial=1))}}
# DEBUG - new_out: defaultdict(<class 'dict'>,
#             {State(pc_initial=0 nstack_initial=0): {'$phi48.0': '$46get_iter.8'},
#              State(pc_initial=48 nstack_initial=1): {'$phi52.1': '$48for_iter.2'}})
# DEBUG - ----------------------DONE Prune PHIs-----------------------
# DEBUG - block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'idx': 0, 'res': '$4load_global.0'}), (14, {'res': '$shape14.2'}), (16, {'func': '$4load_global.0', 'args': ['$shape14.2'], 'kw_names': None, 'res': '$16call.3'}), (24, {'value': '$16call.3'}), (26, {'idx': 1, 'res': '$26load_global.4'}), (36, {'res': '$n36.6'}), (38, {'func': '$26load_global.4', 'args': ['$n36.6'], 'kw_names': None, 'res': '$38call.7'}), (46, {'value': '$38call.7', 'res': '$46get_iter.8'})), outgoing_phis={'$phi48.0': '$46get_iter.8'}, blockstack=(), active_try_block=None, outgoing_edgepushed={48: ('$46get_iter.8',)})
# DEBUG - block_infos State(pc_initial=48 nstack_initial=1):
# AdaptBlockInfo(insts=((48, {'iterator': '$phi48.0', 'pair': '$48for_iter.1', 'indval': '$48for_iter.2', 'pred': '$48for_iter.3'}),), outgoing_phis={'$phi52.1': '$48for_iter.2'}, blockstack=(), active_try_block=None, outgoing_edgepushed={130: ('$phi48.0', '$48for_iter.2'), 52: ('$phi48.0', '$48for_iter.2')})
# DEBUG - block_infos State(pc_initial=52 nstack_initial=2):
# AdaptBlockInfo(insts=((52, {'value': '$phi52.1'}), (54, {'res': '$shape54.2'}), (56, {'res': '$i56.3'}), (58, {'index': '$i56.3', 'target': '$shape54.2', 'res': '$58binary_subscr.4'}), (62, {'res': '$main_shape62.5'}), (64, {'idx': 0, 'res': '$64load_global.6'}), (74, {'res': '$main_shape74.8'}), (76, {'func': '$64load_global.6', 'args': ['$main_shape74.8'], 'kw_names': None, 'res': '$76call.9'}), (84, {'res': '$n84.10'}), (86, {'op': '-', 'lhs': '$76call.9', 'rhs': '$n84.10', 'res': '$binop_sub86.11'}), (90, {'res': '$i90.12'}), (92, {'op': '+', 'lhs': '$binop_sub86.11', 'rhs': '$i90.12', 'res': '$binop_add92.13'}), (96, {'index': '$binop_add92.13', 'target': '$main_shape62.5', 'res': '$96binary_subscr.14'}), (100, {'lhs': '$58binary_subscr.4', 'rhs': '$96binary_subscr.14', 'res': '$100compare_op.15'}), (104, {'pred': '$100compare_op.15'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={106: ('$phi52.0',), 108: ('$phi52.0',)})
# DEBUG - block_infos State(pc_initial=106 nstack_initial=1):
# AdaptBlockInfo(insts=((106, {}),), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={48: ('$phi106.0',)})
# DEBUG - block_infos State(pc_initial=108 nstack_initial=1):
# AdaptBlockInfo(insts=((108, {'idx': 2, 'res': '$108load_global.1'}), (118, {'res': '$const118.3'}), (120, {'func': '$108load_global.1', 'args': ['$const118.3'], 'kw_names': None, 'res': '$120call.4'}), (128, {'exc': '$120call.4'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG - block_infos State(pc_initial=130 nstack_initial=2):
# AdaptBlockInfo(insts=((132, {'retval': '$const132.2', 'castval': '$132return_const.3'}),), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG - label 0:
#     shape = arg(0, name=shape)               ['shape']
#     main_shape = arg(1, name=main_shape)     ['main_shape']
#     $4load_global.0 = global(len: <built-in function len>) ['$4load_global.0']
#     n = call $4load_global.0(shape, func=$4load_global.0, args=[Var(shape, arrayobj.py:3535)], kws=(), vararg=None, varkwarg=None, target=None) ['$4load_global.0', 'n', 'shape']
#     $26load_global.4 = global(range: <class 'range'>) ['$26load_global.4']
#     $38call.7 = call $26load_global.4(n, func=$26load_global.4, args=[Var(n, arrayobj.py:3536)], kws=(), vararg=None, varkwarg=None, target=None) ['$26load_global.4', '$38call.7', 'n']
#     $46get_iter.8 = getiter(value=$38call.7) ['$38call.7', '$46get_iter.8']
#     $phi48.0 = $46get_iter.8                 ['$46get_iter.8', '$phi48.0']
#     jump 48                                  []
# label 48:
#     $48for_iter.1 = iternext(value=$phi48.0) ['$48for_iter.1', '$phi48.0']
#     $48for_iter.2 = pair_first(value=$48for_iter.1) ['$48for_iter.1', '$48for_iter.2']
#     $48for_iter.3 = pair_second(value=$48for_iter.1) ['$48for_iter.1', '$48for_iter.3']
#     $phi52.1 = $48for_iter.2                 ['$48for_iter.2', '$phi52.1']
#     branch $48for_iter.3, 52, 130            ['$48for_iter.3']
# label 52:
#     i = $phi52.1                             ['$phi52.1', 'i']
#     $58binary_subscr.4 = getitem(value=shape, index=i, fn=<built-in function getitem>) ['$58binary_subscr.4', 'i', 'shape']
#     $64load_global.6 = global(len: <built-in function len>) ['$64load_global.6']
#     $76call.9 = call $64load_global.6(main_shape, func=$64load_global.6, args=[Var(main_shape, arrayobj.py:3535)], kws=(), vararg=None, varkwarg=None, target=None) ['$64load_global.6', '$76call.9', 'main_shape']
#     $binop_sub86.11 = $76call.9 - n          ['$76call.9', '$binop_sub86.11', 'n']
#     $binop_add92.13 = $binop_sub86.11 + i    ['$binop_add92.13', '$binop_sub86.11', 'i']
#     $96binary_subscr.14 = getitem(value=main_shape, index=$binop_add92.13, fn=<built-in function getitem>) ['$96binary_subscr.14', '$binop_add92.13', 'main_shape']
#     $100compare_op.15 = $58binary_subscr.4 != $96binary_subscr.14 ['$100compare_op.15', '$58binary_subscr.4', '$96binary_subscr.14']
#     bool104 = global(bool: <class 'bool'>)   ['bool104']
#     $104pred = call bool104($100compare_op.15, func=bool104, args=(Var($100compare_op.15, arrayobj.py:3538),), kws=(), vararg=None, varkwarg=None, target=None) ['$100compare_op.15', '$104pred', 'bool104']
#     branch $104pred, 108, 106                ['$104pred']
# label 106:
#     jump 48                                  []
# label 108:
#     $108load_global.1 = global(ValueError: <class 'ValueError'>) ['$108load_global.1']
#     $const118.3 = const(str, nditer(): operands could not be broadcast together) ['$const118.3']
#     $120call.4 = call $108load_global.1($const118.3, func=$108load_global.1, args=[Var($const118.3, arrayobj.py:3539)], kws=(), vararg=None, varkwarg=None, target=None) ['$108load_global.1', '$120call.4', '$const118.3']
#     raise $120call.4                         ['$120call.4']
# label 130:
#     $const132.2 = const(NoneType, None)      ['$const132.2']
#     $132return_const.3 = cast(value=$const132.2) ['$132return_const.3', '$const132.2']
#     return $132return_const.3                ['$132return_const.3']
#
# DEBUG - ==== SSA block analysis pass on 0
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2C21AF0>
# DEBUG - on stmt: shape = arg(0, name=shape)
# DEBUG - on stmt: main_shape = arg(1, name=main_shape)
# DEBUG - on stmt: $4load_global.0 = global(len: <built-in function len>)
# DEBUG - on stmt: n = const(int, 1)
# DEBUG - on stmt: $26load_global.4 = global(range: <class 'range'>)
# DEBUG - on stmt: $38call.7 = call $26load_global.4(n, func=$26load_global.4, args=[Var(n, arrayobj.py:3536)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: $46get_iter.8 = getiter(value=$38call.7)
# DEBUG - on stmt: $phi48.0 = $46get_iter.8
# DEBUG - on stmt: jump 48
# DEBUG - ==== SSA block analysis pass on 48
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2C21AF0>
# DEBUG - on stmt: $48for_iter.1 = iternext(value=$phi48.0)
# DEBUG - on stmt: $48for_iter.2 = pair_first(value=$48for_iter.1)
# DEBUG - on stmt: $48for_iter.3 = pair_second(value=$48for_iter.1)
# DEBUG - on stmt: $phi52.1 = $48for_iter.2
# DEBUG - on stmt: branch $48for_iter.3, 52, 130
# DEBUG - ==== SSA block analysis pass on 52
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2C21AF0>
# DEBUG - on stmt: i = $phi52.1
# DEBUG - on stmt: $58binary_subscr.4 = getitem(value=shape, index=i, fn=<built-in function getitem>)
# DEBUG - on stmt: $64load_global.6 = global(len: <built-in function len>)
# DEBUG - on stmt: $76call.9 = const(int, 1)
# DEBUG - on stmt: $binop_sub86.11 = $76call.9 - n
# DEBUG - on stmt: $binop_add92.13 = $binop_sub86.11 + i
# DEBUG - on stmt: $96binary_subscr.14 = getitem(value=main_shape, index=$binop_add92.13, fn=<built-in function getitem>)
# DEBUG - on stmt: $100compare_op.15 = $58binary_subscr.4 != $96binary_subscr.14
# DEBUG - on stmt: bool104 = global(bool: <class 'bool'>)
# DEBUG - on stmt: $104pred = call bool104($100compare_op.15, func=bool104, args=(Var($100compare_op.15, arrayobj.py:3538),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: branch $104pred, 108, 106
# DEBUG - ==== SSA block analysis pass on 106
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2C21AF0>
# DEBUG - on stmt: jump 48
# DEBUG - ==== SSA block analysis pass on 108
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2C21AF0>
# DEBUG - on stmt: $108load_global.1 = global(ValueError: <class 'ValueError'>)
# DEBUG - on stmt: $const118.3 = const(str, nditer(): operands could not be broadcast together)
# DEBUG - on stmt: $120call.4 = call $108load_global.1($const118.3, func=$108load_global.1, args=[Var($const118.3, arrayobj.py:3539)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG - on stmt: <static> raise <class 'ValueError'>('nditer(): operands could not be broadcast together')
# DEBUG - ==== SSA block analysis pass on 130
# DEBUG - Running <numba.core.ssa._GatherDefsHandler object at 0x00000169D2C21AF0>
# DEBUG - on stmt: $const132.2 = const(NoneType, None)
# DEBUG - on stmt: $132return_const.3 = cast(value=$const132.2)
# DEBUG - on stmt: return $132return_const.3
# DEBUG - defs defaultdict(<class 'list'>,
#             {'$100compare_op.15': [(<numba.core.ir.Assign object at 0x00000169D2C423F0>,
#                                     52)],
#              '$104pred': [(<numba.core.ir.Assign object at 0x00000169D2C42600>,
#                            52)],
#              '$108load_global.1': [(<numba.core.ir.Assign object at 0x00000169D2C426C0>,
#                                     108)],
#              '$120call.4': [(<numba.core.ir.Assign object at 0x00000169D2C42990>,
#                              108)],
#              '$132return_const.3': [(<numba.core.ir.Assign object at 0x00000169D2C42C30>,
#                                      130)],
#              '$26load_global.4': [(<numba.core.ir.Assign object at 0x00000169D2C40B60>,
#                                    0)],
#              '$38call.7': [(<numba.core.ir.Assign object at 0x00000169D2C40E00>,
#                             0)],
#              '$46get_iter.8': [(<numba.core.ir.Assign object at 0x00000169D2C40EF0>,
#                                 0)],
#              '$48for_iter.1': [(<numba.core.ir.Assign object at 0x00000169D2C410D0>,
#                                 48)],
#              '$48for_iter.2': [(<numba.core.ir.Assign object at 0x00000169D2C411F0>,
#                                 48)],
#              '$48for_iter.3': [(<numba.core.ir.Assign object at 0x00000169D2C41310>,
#                                 48)],
#              '$4load_global.0': [(<numba.core.ir.Assign object at 0x00000169D2C406E0>,
#                                   0)],
#              '$58binary_subscr.4': [(<numba.core.ir.Assign object at 0x00000169D2C41880>,
#                                      52)],
#              '$64load_global.6': [(<numba.core.ir.Assign object at 0x00000169D2C41A60>,
#                                    52)],
#              '$76call.9': [(<numba.core.ir.Assign object at 0x00000169D2C41D00>,
#                             52)],
#              '$96binary_subscr.14': [(<numba.core.ir.Assign object at 0x00000169D2C422D0>,
#                                       52)],
#              '$binop_add92.13': [(<numba.core.ir.Assign object at 0x00000169D2C42180>,
#                                   52)],
#              '$binop_sub86.11': [(<numba.core.ir.Assign object at 0x00000169D2C41F40>,
#                                   52)],
#              '$const118.3': [(<numba.core.ir.Assign object at 0x00000169D2C427E0>,
#                               108)],
#              '$const132.2': [(<numba.core.ir.Assign object at 0x00000169D2C42B10>,
#                               130)],
#              '$phi48.0': [(<numba.core.ir.Assign object at 0x00000169D2C40A70>,
#                            0)],
#              '$phi52.1': [(<numba.core.ir.Assign object at 0x00000169D2C40FE0>,
#                            48)],
#              'bool104': [(<numba.core.ir.Assign object at 0x00000169D2C42510>,
#                           52)],
#              'i': [(<numba.core.ir.Assign object at 0x00000169D2C41520>, 52)],
#              'main_shape': [(<numba.core.ir.Assign object at 0x00000169D2C40590>,
#                              0)],
#              'n': [(<numba.core.ir.Assign object at 0x00000169D2C409B0>, 0)],
#              'shape': [(<numba.core.ir.Assign object at 0x00000169D2C404A0>,
#                         0)]})
# DEBUG - SSA violators <numba.core.utils.OrderedSet object at 0x00000169D2B8B920>
# 71.2 μs ± 27.1 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)
