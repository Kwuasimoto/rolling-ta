# %%
# Append rolling_ta to sys path.
import sys
import os

# Assuming rolling_ta is in the same level as tests/
module_path = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))

# Add the path to sys.path
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from ta.momentum import RSIIndicator
from rolling_ta.momentum import NumbaRSI
from rolling_ta.data import CSVLoader

# %%
csv_loader = CSVLoader()
data = csv_loader.read_resource()
# Out:
# DEBUG - CSVLoader: Loading from resources/btc_ohlcv.csv

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   timestamp  10000 non-null  float64
#  1   open       10000 non-null  float64
#  2   high       10000 non-null  float64
#  3   low        10000 non-null  float64
#  4   close      10000 non-null  float64
#  5   volume     10000 non-null  float64
# dtypes: float64(6)
# memory usage: 468.9 KB

# %%
NumbaRSI(data, memory=False)
# Out:
# DEBUG - bytecode dump:
# >          0	NOP(arg=None, lineno=218)
#            2	RESUME(arg=0, lineno=218)
#            4	LOAD_FAST(arg=0, lineno=231)
#            6	LOAD_ATTR(arg=0, lineno=231)
#           26	STORE_FAST(arg=6, lineno=231)
#           28	LOAD_GLOBAL(arg=3, lineno=234)
#           38	LOAD_ATTR(arg=4, lineno=234)
#           58	LOAD_CONST(arg=1, lineno=234)
#           60	LOAD_FAST(arg=6, lineno=234)
#           62	CALL(arg=2, lineno=234)
#           70	GET_ITER(arg=None, lineno=234)
# >         72	FOR_ITER(arg=39, lineno=234)
#           76	STORE_FAST(arg=7, lineno=234)
#           78	LOAD_FAST(arg=0, lineno=235)
#           80	LOAD_FAST(arg=7, lineno=235)
#           82	BINARY_SUBSCR(arg=None, lineno=235)
#           86	LOAD_FAST(arg=0, lineno=235)
#           88	LOAD_FAST(arg=7, lineno=235)
#           90	LOAD_CONST(arg=1, lineno=235)
#           92	BINARY_OP(arg=10, lineno=235)
#           96	BINARY_SUBSCR(arg=None, lineno=235)
#          100	BINARY_OP(arg=10, lineno=235)
#          104	STORE_FAST(arg=8, lineno=235)
#          106	LOAD_FAST(arg=8, lineno=236)
#          108	LOAD_CONST(arg=2, lineno=236)
#          110	COMPARE_OP(arg=68, lineno=236)
#          114	POP_JUMP_IF_FALSE(arg=6, lineno=236)
#          116	LOAD_FAST(arg=8, lineno=237)
#          118	LOAD_FAST(arg=2, lineno=237)
#          120	LOAD_FAST(arg=7, lineno=237)
#          122	STORE_SUBSCR(arg=None, lineno=237)
#          126	JUMP_BACKWARD(arg=28, lineno=237)
# >        128	LOAD_FAST(arg=8, lineno=238)
#          130	LOAD_CONST(arg=2, lineno=238)
#          132	COMPARE_OP(arg=2, lineno=238)
#          136	POP_JUMP_IF_TRUE(arg=1, lineno=238)
#          138	JUMP_BACKWARD(arg=34, lineno=238)
# >        140	LOAD_FAST(arg=8, lineno=239)
#          142	UNARY_NEGATIVE(arg=None, lineno=239)
#          144	LOAD_FAST(arg=3, lineno=239)
#          146	LOAD_FAST(arg=7, lineno=239)
#          148	STORE_SUBSCR(arg=None, lineno=239)
#          152	JUMP_BACKWARD(arg=41, lineno=239)
# >        154	END_FOR(arg=None, lineno=234)
#          156	LOAD_GLOBAL(arg=7, lineno=241)
#          166	LOAD_FAST(arg=2, lineno=241)
#          168	LOAD_CONST(arg=1, lineno=241)
#          170	LOAD_FAST(arg=4, lineno=241)
#          172	LOAD_CONST(arg=1, lineno=241)
#          174	BINARY_OP(arg=0, lineno=241)
#          178	BINARY_SLICE(arg=None, lineno=241)
#          180	CALL(arg=1, lineno=241)
#          188	STORE_FAST(arg=9, lineno=241)
#          190	LOAD_GLOBAL(arg=7, lineno=242)
#          200	LOAD_FAST(arg=3, lineno=242)
#          202	LOAD_CONST(arg=1, lineno=242)
#          204	LOAD_FAST(arg=4, lineno=242)
#          206	LOAD_CONST(arg=1, lineno=242)
#          208	BINARY_OP(arg=0, lineno=242)
#          212	BINARY_SLICE(arg=None, lineno=242)
#          214	CALL(arg=1, lineno=242)
#          222	STORE_FAST(arg=10, lineno=242)
#          224	LOAD_CONST(arg=3, lineno=244)
#          226	LOAD_FAST(arg=9, lineno=244)
#          228	BINARY_OP(arg=5, lineno=244)
#          232	LOAD_FAST(arg=9, lineno=244)
#          234	LOAD_FAST(arg=10, lineno=244)
#          236	BINARY_OP(arg=0, lineno=244)
#          240	BINARY_OP(arg=11, lineno=244)
#          244	LOAD_FAST(arg=1, lineno=244)
#          246	LOAD_FAST(arg=4, lineno=244)
#          248	STORE_SUBSCR(arg=None, lineno=244)
#          252	LOAD_GLOBAL(arg=9, lineno=247)
#          262	LOAD_FAST(arg=4, lineno=247)
#          264	LOAD_CONST(arg=1, lineno=247)
#          266	BINARY_OP(arg=0, lineno=247)
#          270	LOAD_FAST(arg=6, lineno=247)
#          272	CALL(arg=2, lineno=247)
#          280	GET_ITER(arg=None, lineno=247)
# >        282	FOR_ITER(arg=44, lineno=247)
#          286	STORE_FAST(arg=7, lineno=247)
#          288	LOAD_FAST(arg=9, lineno=248)
#          290	LOAD_FAST(arg=5, lineno=248)
#          292	BINARY_OP(arg=5, lineno=248)
#          296	LOAD_FAST(arg=2, lineno=248)
#          298	LOAD_FAST(arg=7, lineno=248)
#          300	BINARY_SUBSCR(arg=None, lineno=248)
#          304	BINARY_OP(arg=0, lineno=248)
#          308	LOAD_FAST(arg=4, lineno=248)
#          310	BINARY_OP(arg=11, lineno=248)
#          314	STORE_FAST(arg=9, lineno=248)
#          316	LOAD_FAST(arg=10, lineno=249)
#          318	LOAD_FAST(arg=5, lineno=249)
#          320	BINARY_OP(arg=5, lineno=249)
#          324	LOAD_FAST(arg=3, lineno=249)
#          326	LOAD_FAST(arg=7, lineno=249)
#          328	BINARY_SUBSCR(arg=None, lineno=249)
#          332	BINARY_OP(arg=0, lineno=249)
#          336	LOAD_FAST(arg=4, lineno=249)
#          338	BINARY_OP(arg=11, lineno=249)
#          342	STORE_FAST(arg=10, lineno=249)
#          344	LOAD_CONST(arg=3, lineno=250)
#          346	LOAD_FAST(arg=9, lineno=250)
#          348	BINARY_OP(arg=5, lineno=250)
#          352	LOAD_FAST(arg=9, lineno=250)
#          354	LOAD_FAST(arg=10, lineno=250)
#          356	BINARY_OP(arg=0, lineno=250)
#          360	BINARY_OP(arg=11, lineno=250)
#          364	LOAD_FAST(arg=1, lineno=250)
#          366	LOAD_FAST(arg=7, lineno=250)
#          368	STORE_SUBSCR(arg=None, lineno=250)
#          372	JUMP_BACKWARD(arg=46, lineno=250)
# >        374	END_FOR(arg=None, lineno=247)
#          376	LOAD_FAST(arg=1, lineno=252)
#          378	LOAD_FAST(arg=9, lineno=252)
#          380	LOAD_FAST(arg=10, lineno=252)
#          382	LOAD_FAST(arg=0, lineno=252)
#          384	LOAD_CONST(arg=4, lineno=252)
#          386	BINARY_SUBSCR(arg=None, lineno=252)
#          390	BUILD_TUPLE(arg=4, lineno=252)
#          392	RETURN_VALUE(arg=None, lineno=252)
# DEBUG - pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG - stack: []
# DEBUG - state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG - dispatch pc=0, inst=NOP(arg=None, lineno=218)
# DEBUG - stack []
# DEBUG - dispatch pc=2, inst=RESUME(arg=0, lineno=218)
# DEBUG - stack []
# DEBUG - dispatch pc=4, inst=LOAD_FAST(arg=0, lineno=231)
# DEBUG - stack []
# DEBUG - dispatch pc=6, inst=LOAD_ATTR(arg=0, lineno=231)
# DEBUG - stack ['$close4.0']
# DEBUG - dispatch pc=26, inst=STORE_FAST(arg=6, lineno=231)
# DEBUG - stack ['$6load_attr.1']
# DEBUG - dispatch pc=28, inst=LOAD_GLOBAL(arg=3, lineno=234)
# DEBUG - stack []
# DEBUG - dispatch pc=38, inst=LOAD_ATTR(arg=4, lineno=234)
# DEBUG - stack ['$null$28.3', '$28load_global.2']
# DEBUG - dispatch pc=58, inst=LOAD_CONST(arg=1, lineno=234)
# DEBUG - stack ['$null$28.3', '$38load_attr.4']
# DEBUG - dispatch pc=60, inst=LOAD_FAST(arg=6, lineno=234)
# DEBUG - stack ['$null$28.3', '$38load_attr.4', '$const58.5']
# DEBUG - dispatch pc=62, inst=CALL(arg=2, lineno=234)
# DEBUG - stack ['$null$28.3', '$38load_attr.4', '$const58.5', '$n60.6']
# DEBUG - dispatch pc=70, inst=GET_ITER(arg=None, lineno=234)
# DEBUG - stack ['$62call.7']
# DEBUG - end state. edges=[Edge(pc=72, stack=('$70get_iter.8',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=72 nstack_initial=1)])
# DEBUG - stack: ['$phi72.0']
# DEBUG - state.pc_initial: State(pc_initial=72 nstack_initial=1)
# DEBUG - dispatch pc=72, inst=FOR_ITER(arg=39, lineno=234)
# DEBUG - stack ['$phi72.0']
# DEBUG - end state. edges=[Edge(pc=154, stack=('$phi72.0', '$72for_iter.2'), blockstack=(), npush=0), Edge(pc=76, stack=('$phi72.0', '$72for_iter.2'), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=154 nstack_initial=2), State(pc_initial=76 nstack_initial=2)])
# DEBUG - stack: ['$phi154.0', '$phi154.1']
# DEBUG - state.pc_initial: State(pc_initial=154 nstack_initial=2)
# DEBUG - dispatch pc=154, inst=END_FOR(arg=None, lineno=234)
# DEBUG - stack ['$phi154.0', '$phi154.1']
# DEBUG - dispatch pc=156, inst=LOAD_GLOBAL(arg=7, lineno=241)
# DEBUG - stack []
# DEBUG - dispatch pc=166, inst=LOAD_FAST(arg=2, lineno=241)
# DEBUG - stack ['$null$156.3', '$156load_global.2']
# DEBUG - dispatch pc=168, inst=LOAD_CONST(arg=1, lineno=241)
# DEBUG - stack ['$null$156.3', '$156load_global.2', '$gains_container166.4']
# DEBUG - dispatch pc=170, inst=LOAD_FAST(arg=4, lineno=241)
# DEBUG - stack ['$null$156.3', '$156load_global.2', '$gains_container166.4', '$const168.5']
# DEBUG - dispatch pc=172, inst=LOAD_CONST(arg=1, lineno=241)
# DEBUG - stack ['$null$156.3', '$156load_global.2', '$gains_container166.4', '$const168.5', '$period170.6']
# DEBUG - dispatch pc=174, inst=BINARY_OP(arg=0, lineno=241)
# DEBUG - stack ['$null$156.3', '$156load_global.2', '$gains_container166.4', '$const168.5', '$period170.6', '$const172.7']
# DEBUG - dispatch pc=178, inst=BINARY_SLICE(arg=None, lineno=241)
# DEBUG - stack ['$null$156.3', '$156load_global.2', '$gains_container166.4', '$const168.5', '$binop_add174.8']
# DEBUG - dispatch pc=180, inst=CALL(arg=1, lineno=241)
# DEBUG - stack ['$null$156.3', '$156load_global.2', '$178binary_slice.10']
# DEBUG - dispatch pc=188, inst=STORE_FAST(arg=9, lineno=241)
# DEBUG - stack ['$180call.12']
# DEBUG - dispatch pc=190, inst=LOAD_GLOBAL(arg=7, lineno=242)
# DEBUG - stack []
# DEBUG - dispatch pc=200, inst=LOAD_FAST(arg=3, lineno=242)
# DEBUG - stack ['$null$190.14', '$190load_global.13']
# DEBUG - dispatch pc=202, inst=LOAD_CONST(arg=1, lineno=242)
# DEBUG - stack ['$null$190.14', '$190load_global.13', '$losses_container200.15']
# DEBUG - dispatch pc=204, inst=LOAD_FAST(arg=4, lineno=242)
# DEBUG - stack ['$null$190.14', '$190load_global.13', '$losses_container200.15', '$const202.16']
# DEBUG - dispatch pc=206, inst=LOAD_CONST(arg=1, lineno=242)
# DEBUG - stack ['$null$190.14', '$190load_global.13', '$losses_container200.15', '$const202.16', '$period204.17']
# DEBUG - dispatch pc=208, inst=BINARY_OP(arg=0, lineno=242)
# DEBUG - stack ['$null$190.14', '$190load_global.13', '$losses_container200.15', '$const202.16', '$period204.17', '$const206.18']
# DEBUG - dispatch pc=212, inst=BINARY_SLICE(arg=None, lineno=242)
# DEBUG - stack ['$null$190.14', '$190load_global.13', '$losses_container200.15', '$const202.16', '$binop_add208.19']
# DEBUG - dispatch pc=214, inst=CALL(arg=1, lineno=242)
# DEBUG - stack ['$null$190.14', '$190load_global.13', '$212binary_slice.21']
# DEBUG - dispatch pc=222, inst=STORE_FAST(arg=10, lineno=242)
# DEBUG - stack ['$214call.23']
# DEBUG - dispatch pc=224, inst=LOAD_CONST(arg=3, lineno=244)
# DEBUG - stack []
# DEBUG - dispatch pc=226, inst=LOAD_FAST(arg=9, lineno=244)
# DEBUG - stack ['$const224.24']
# DEBUG - dispatch pc=228, inst=BINARY_OP(arg=5, lineno=244)
# DEBUG - stack ['$const224.24', '$avg_gain226.25']
# DEBUG - dispatch pc=232, inst=LOAD_FAST(arg=9, lineno=244)
# DEBUG - stack ['$binop_mul228.26']
# DEBUG - dispatch pc=234, inst=LOAD_FAST(arg=10, lineno=244)
# DEBUG - stack ['$binop_mul228.26', '$avg_gain232.27']
# DEBUG - dispatch pc=236, inst=BINARY_OP(arg=0, lineno=244)
# DEBUG - stack ['$binop_mul228.26', '$avg_gain232.27', '$avg_loss234.28']
# DEBUG - dispatch pc=240, inst=BINARY_OP(arg=11, lineno=244)
# DEBUG - stack ['$binop_mul228.26', '$binop_add236.29']
# DEBUG - dispatch pc=244, inst=LOAD_FAST(arg=1, lineno=244)
# DEBUG - stack ['$binop_truediv240.30']
# DEBUG - dispatch pc=246, inst=LOAD_FAST(arg=4, lineno=244)
# DEBUG - stack ['$binop_truediv240.30', '$rsi_container244.31']
# DEBUG - dispatch pc=248, inst=STORE_SUBSCR(arg=None, lineno=244)
# DEBUG - stack ['$binop_truediv240.30', '$rsi_container244.31', '$period246.32']
# DEBUG - dispatch pc=252, inst=LOAD_GLOBAL(arg=9, lineno=247)
# DEBUG - stack []
# DEBUG - dispatch pc=262, inst=LOAD_FAST(arg=4, lineno=247)
# DEBUG - stack ['$null$252.34', '$252load_global.33']
# DEBUG - dispatch pc=264, inst=LOAD_CONST(arg=1, lineno=247)
# DEBUG - stack ['$null$252.34', '$252load_global.33', '$period262.35']
# DEBUG - dispatch pc=266, inst=BINARY_OP(arg=0, lineno=247)
# DEBUG - stack ['$null$252.34', '$252load_global.33', '$period262.35', '$const264.36']
# DEBUG - dispatch pc=270, inst=LOAD_FAST(arg=6, lineno=247)
# DEBUG - stack ['$null$252.34', '$252load_global.33', '$binop_add266.37']
# DEBUG - dispatch pc=272, inst=CALL(arg=2, lineno=247)
# DEBUG - stack ['$null$252.34', '$252load_global.33', '$binop_add266.37', '$n270.38']
# DEBUG - dispatch pc=280, inst=GET_ITER(arg=None, lineno=247)
# DEBUG - stack ['$272call.39']
# DEBUG - end state. edges=[Edge(pc=282, stack=('$280get_iter.40',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=76 nstack_initial=2), State(pc_initial=282 nstack_initial=1)])
# DEBUG - stack: ['$phi76.0', '$phi76.1']
# DEBUG - state.pc_initial: State(pc_initial=76 nstack_initial=2)
# DEBUG - dispatch pc=76, inst=STORE_FAST(arg=7, lineno=234)
# DEBUG - stack ['$phi76.0', '$phi76.1']
# DEBUG - dispatch pc=78, inst=LOAD_FAST(arg=0, lineno=235)
# DEBUG - stack ['$phi76.0']
# DEBUG - dispatch pc=80, inst=LOAD_FAST(arg=7, lineno=235)
# DEBUG - stack ['$phi76.0', '$close78.2']
# DEBUG - dispatch pc=82, inst=BINARY_SUBSCR(arg=None, lineno=235)
# DEBUG - stack ['$phi76.0', '$close78.2', '$i80.3']
# DEBUG - dispatch pc=86, inst=LOAD_FAST(arg=0, lineno=235)
# DEBUG - stack ['$phi76.0', '$82binary_subscr.4']
# DEBUG - dispatch pc=88, inst=LOAD_FAST(arg=7, lineno=235)
# DEBUG - stack ['$phi76.0', '$82binary_subscr.4', '$close86.5']
# DEBUG - dispatch pc=90, inst=LOAD_CONST(arg=1, lineno=235)
# DEBUG - stack ['$phi76.0', '$82binary_subscr.4', '$close86.5', '$i88.6']
# DEBUG - dispatch pc=92, inst=BINARY_OP(arg=10, lineno=235)
# DEBUG - stack ['$phi76.0', '$82binary_subscr.4', '$close86.5', '$i88.6', '$const90.7']
# DEBUG - dispatch pc=96, inst=BINARY_SUBSCR(arg=None, lineno=235)
# DEBUG - stack ['$phi76.0', '$82binary_subscr.4', '$close86.5', '$binop_sub92.8']
# DEBUG - dispatch pc=100, inst=BINARY_OP(arg=10, lineno=235)
# DEBUG - stack ['$phi76.0', '$82binary_subscr.4', '$96binary_subscr.9']
# DEBUG - dispatch pc=104, inst=STORE_FAST(arg=8, lineno=235)
# DEBUG - stack ['$phi76.0', '$binop_sub100.10']
# DEBUG - dispatch pc=106, inst=LOAD_FAST(arg=8, lineno=236)
# DEBUG - stack ['$phi76.0']
# DEBUG - dispatch pc=108, inst=LOAD_CONST(arg=2, lineno=236)
# DEBUG - stack ['$phi76.0', '$delta106.11']
# DEBUG - dispatch pc=110, inst=COMPARE_OP(arg=68, lineno=236)
# DEBUG - stack ['$phi76.0', '$delta106.11', '$const108.12']
# DEBUG - dispatch pc=114, inst=POP_JUMP_IF_FALSE(arg=6, lineno=236)
# DEBUG - stack ['$phi76.0', '$110compare_op.13']
# DEBUG - end state. edges=[Edge(pc=116, stack=('$phi76.0',), blockstack=(), npush=0), Edge(pc=128, stack=('$phi76.0',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=282 nstack_initial=1), State(pc_initial=116 nstack_initial=1), State(pc_initial=128 nstack_initial=1)])
# DEBUG - stack: ['$phi282.0']
# DEBUG - state.pc_initial: State(pc_initial=282 nstack_initial=1)
# DEBUG - dispatch pc=282, inst=FOR_ITER(arg=44, lineno=247)
# DEBUG - stack ['$phi282.0']
# DEBUG - end state. edges=[Edge(pc=374, stack=('$phi282.0', '$282for_iter.2'), blockstack=(), npush=0), Edge(pc=286, stack=('$phi282.0', '$282for_iter.2'), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=116 nstack_initial=1), State(pc_initial=128 nstack_initial=1), State(pc_initial=374 nstack_initial=2), State(pc_initial=286 nstack_initial=2)])
# DEBUG - stack: ['$phi116.0']
# DEBUG - state.pc_initial: State(pc_initial=116 nstack_initial=1)
# DEBUG - dispatch pc=116, inst=LOAD_FAST(arg=8, lineno=237)
# DEBUG - stack ['$phi116.0']
# DEBUG - dispatch pc=118, inst=LOAD_FAST(arg=2, lineno=237)
# DEBUG - stack ['$phi116.0', '$delta116.1']
# DEBUG - dispatch pc=120, inst=LOAD_FAST(arg=7, lineno=237)
# DEBUG - stack ['$phi116.0', '$delta116.1', '$gains_container118.2']
# DEBUG - dispatch pc=122, inst=STORE_SUBSCR(arg=None, lineno=237)
# DEBUG - stack ['$phi116.0', '$delta116.1', '$gains_container118.2', '$i120.3']
# DEBUG - dispatch pc=126, inst=JUMP_BACKWARD(arg=28, lineno=237)
# DEBUG - stack ['$phi116.0']
# DEBUG - end state. edges=[Edge(pc=72, stack=('$phi116.0',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=128 nstack_initial=1), State(pc_initial=374 nstack_initial=2), State(pc_initial=286 nstack_initial=2), State(pc_initial=72 nstack_initial=1)])
# DEBUG - stack: ['$phi128.0']
# DEBUG - state.pc_initial: State(pc_initial=128 nstack_initial=1)
# DEBUG - dispatch pc=128, inst=LOAD_FAST(arg=8, lineno=238)
# DEBUG - stack ['$phi128.0']
# DEBUG - dispatch pc=130, inst=LOAD_CONST(arg=2, lineno=238)
# DEBUG - stack ['$phi128.0', '$delta128.1']
# DEBUG - dispatch pc=132, inst=COMPARE_OP(arg=2, lineno=238)
# DEBUG - stack ['$phi128.0', '$delta128.1', '$const130.2']
# DEBUG - dispatch pc=136, inst=POP_JUMP_IF_TRUE(arg=1, lineno=238)
# DEBUG - stack ['$phi128.0', '$132compare_op.3']
# DEBUG - end state. edges=[Edge(pc=138, stack=('$phi128.0',), blockstack=(), npush=0), Edge(pc=140, stack=('$phi128.0',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=374 nstack_initial=2), State(pc_initial=286 nstack_initial=2), State(pc_initial=72 nstack_initial=1), State(pc_initial=138 nstack_initial=1), State(pc_initial=140 nstack_initial=1)])
# DEBUG - stack: ['$phi374.0', '$phi374.1']
# DEBUG - state.pc_initial: State(pc_initial=374 nstack_initial=2)
# DEBUG - dispatch pc=374, inst=END_FOR(arg=None, lineno=247)
# DEBUG - stack ['$phi374.0', '$phi374.1']
# DEBUG - dispatch pc=376, inst=LOAD_FAST(arg=1, lineno=252)
# DEBUG - stack []
# DEBUG - dispatch pc=378, inst=LOAD_FAST(arg=9, lineno=252)
# DEBUG - stack ['$rsi_container376.2']
# DEBUG - dispatch pc=380, inst=LOAD_FAST(arg=10, lineno=252)
# DEBUG - stack ['$rsi_container376.2', '$avg_gain378.3']
# DEBUG - dispatch pc=382, inst=LOAD_FAST(arg=0, lineno=252)
# DEBUG - stack ['$rsi_container376.2', '$avg_gain378.3', '$avg_loss380.4']
# DEBUG - dispatch pc=384, inst=LOAD_CONST(arg=4, lineno=252)
# DEBUG - stack ['$rsi_container376.2', '$avg_gain378.3', '$avg_loss380.4', '$close382.5']
# DEBUG - dispatch pc=386, inst=BINARY_SUBSCR(arg=None, lineno=252)
# DEBUG - stack ['$rsi_container376.2', '$avg_gain378.3', '$avg_loss380.4', '$close382.5', '$const384.6']
# DEBUG - dispatch pc=390, inst=BUILD_TUPLE(arg=4, lineno=252)
# DEBUG - stack ['$rsi_container376.2', '$avg_gain378.3', '$avg_loss380.4', '$386binary_subscr.7']
# DEBUG - dispatch pc=392, inst=RETURN_VALUE(arg=None, lineno=252)
# DEBUG - stack ['$390build_tuple.8']
# DEBUG - end state. edges=[]
# DEBUG - pending: deque([State(pc_initial=286 nstack_initial=2), State(pc_initial=72 nstack_initial=1), State(pc_initial=138 nstack_initial=1), State(pc_initial=140 nstack_initial=1)])
# DEBUG - stack: ['$phi286.0', '$phi286.1']
# DEBUG - state.pc_initial: State(pc_initial=286 nstack_initial=2)
# DEBUG - dispatch pc=286, inst=STORE_FAST(arg=7, lineno=247)
# DEBUG - stack ['$phi286.0', '$phi286.1']
# DEBUG - dispatch pc=288, inst=LOAD_FAST(arg=9, lineno=248)
# DEBUG - stack ['$phi286.0']
# DEBUG - dispatch pc=290, inst=LOAD_FAST(arg=5, lineno=248)
# DEBUG - stack ['$phi286.0', '$avg_gain288.2']
# DEBUG - dispatch pc=292, inst=BINARY_OP(arg=5, lineno=248)
# DEBUG - stack ['$phi286.0', '$avg_gain288.2', '$p_1290.3']
# DEBUG - dispatch pc=296, inst=LOAD_FAST(arg=2, lineno=248)
# DEBUG - stack ['$phi286.0', '$binop_mul292.4']
# DEBUG - dispatch pc=298, inst=LOAD_FAST(arg=7, lineno=248)
# DEBUG - stack ['$phi286.0', '$binop_mul292.4', '$gains_container296.5']
# DEBUG - dispatch pc=300, inst=BINARY_SUBSCR(arg=None, lineno=248)
# DEBUG - stack ['$phi286.0', '$binop_mul292.4', '$gains_container296.5', '$i298.6']
# DEBUG - dispatch pc=304, inst=BINARY_OP(arg=0, lineno=248)
# DEBUG - stack ['$phi286.0', '$binop_mul292.4', '$300binary_subscr.7']
# DEBUG - dispatch pc=308, inst=LOAD_FAST(arg=4, lineno=248)
# DEBUG - stack ['$phi286.0', '$binop_add304.8']
# DEBUG - dispatch pc=310, inst=BINARY_OP(arg=11, lineno=248)
# DEBUG - stack ['$phi286.0', '$binop_add304.8', '$period308.9']
# DEBUG - dispatch pc=314, inst=STORE_FAST(arg=9, lineno=248)
# DEBUG - stack ['$phi286.0', '$binop_truediv310.10']
# DEBUG - dispatch pc=316, inst=LOAD_FAST(arg=10, lineno=249)
# DEBUG - stack ['$phi286.0']
# DEBUG - dispatch pc=318, inst=LOAD_FAST(arg=5, lineno=249)
# DEBUG - stack ['$phi286.0', '$avg_loss316.11']
# DEBUG - dispatch pc=320, inst=BINARY_OP(arg=5, lineno=249)
# DEBUG - stack ['$phi286.0', '$avg_loss316.11', '$p_1318.12']
# DEBUG - dispatch pc=324, inst=LOAD_FAST(arg=3, lineno=249)
# DEBUG - stack ['$phi286.0', '$binop_mul320.13']
# DEBUG - dispatch pc=326, inst=LOAD_FAST(arg=7, lineno=249)
# DEBUG - stack ['$phi286.0', '$binop_mul320.13', '$losses_container324.14']
# DEBUG - dispatch pc=328, inst=BINARY_SUBSCR(arg=None, lineno=249)
# DEBUG - stack ['$phi286.0', '$binop_mul320.13', '$losses_container324.14', '$i326.15']
# DEBUG - dispatch pc=332, inst=BINARY_OP(arg=0, lineno=249)
# DEBUG - stack ['$phi286.0', '$binop_mul320.13', '$328binary_subscr.16']
# DEBUG - dispatch pc=336, inst=LOAD_FAST(arg=4, lineno=249)
# DEBUG - stack ['$phi286.0', '$binop_add332.17']
# DEBUG - dispatch pc=338, inst=BINARY_OP(arg=11, lineno=249)
# DEBUG - stack ['$phi286.0', '$binop_add332.17', '$period336.18']
# DEBUG - dispatch pc=342, inst=STORE_FAST(arg=10, lineno=249)
# DEBUG - stack ['$phi286.0', '$binop_truediv338.19']
# DEBUG - dispatch pc=344, inst=LOAD_CONST(arg=3, lineno=250)
# DEBUG - stack ['$phi286.0']
# DEBUG - dispatch pc=346, inst=LOAD_FAST(arg=9, lineno=250)
# DEBUG - stack ['$phi286.0', '$const344.20']
# DEBUG - dispatch pc=348, inst=BINARY_OP(arg=5, lineno=250)
# DEBUG - stack ['$phi286.0', '$const344.20', '$avg_gain346.21']
# DEBUG - dispatch pc=352, inst=LOAD_FAST(arg=9, lineno=250)
# DEBUG - stack ['$phi286.0', '$binop_mul348.22']
# DEBUG - dispatch pc=354, inst=LOAD_FAST(arg=10, lineno=250)
# DEBUG - stack ['$phi286.0', '$binop_mul348.22', '$avg_gain352.23']
# DEBUG - dispatch pc=356, inst=BINARY_OP(arg=0, lineno=250)
# DEBUG - stack ['$phi286.0', '$binop_mul348.22', '$avg_gain352.23', '$avg_loss354.24']
# DEBUG - dispatch pc=360, inst=BINARY_OP(arg=11, lineno=250)
# DEBUG - stack ['$phi286.0', '$binop_mul348.22', '$binop_add356.25']
# DEBUG - dispatch pc=364, inst=LOAD_FAST(arg=1, lineno=250)
# DEBUG - stack ['$phi286.0', '$binop_truediv360.26']
# DEBUG - dispatch pc=366, inst=LOAD_FAST(arg=7, lineno=250)
# DEBUG - stack ['$phi286.0', '$binop_truediv360.26', '$rsi_container364.27']
# DEBUG - dispatch pc=368, inst=STORE_SUBSCR(arg=None, lineno=250)
# DEBUG - stack ['$phi286.0', '$binop_truediv360.26', '$rsi_container364.27', '$i366.28']
# DEBUG - dispatch pc=372, inst=JUMP_BACKWARD(arg=46, lineno=250)
# DEBUG - stack ['$phi286.0']
# DEBUG - end state. edges=[Edge(pc=282, stack=('$phi286.0',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=72 nstack_initial=1), State(pc_initial=138 nstack_initial=1), State(pc_initial=140 nstack_initial=1), State(pc_initial=282 nstack_initial=1)])
# DEBUG - pending: deque([State(pc_initial=138 nstack_initial=1), State(pc_initial=140 nstack_initial=1), State(pc_initial=282 nstack_initial=1)])
# DEBUG - stack: ['$phi138.0']
# DEBUG - state.pc_initial: State(pc_initial=138 nstack_initial=1)
# DEBUG - dispatch pc=138, inst=JUMP_BACKWARD(arg=34, lineno=238)
# DEBUG - stack ['$phi138.0']
# DEBUG - end state. edges=[Edge(pc=72, stack=('$phi138.0',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=140 nstack_initial=1), State(pc_initial=282 nstack_initial=1), State(pc_initial=72 nstack_initial=1)])
# DEBUG - stack: ['$phi140.0']
# DEBUG - state.pc_initial: State(pc_initial=140 nstack_initial=1)
# DEBUG - dispatch pc=140, inst=LOAD_FAST(arg=8, lineno=239)
# DEBUG - stack ['$phi140.0']
# DEBUG - dispatch pc=142, inst=UNARY_NEGATIVE(arg=None, lineno=239)
# DEBUG - stack ['$phi140.0', '$delta140.1']
# DEBUG - dispatch pc=144, inst=LOAD_FAST(arg=3, lineno=239)
# DEBUG - stack ['$phi140.0', '$142unary_negative.2']
# DEBUG - dispatch pc=146, inst=LOAD_FAST(arg=7, lineno=239)
# DEBUG - stack ['$phi140.0', '$142unary_negative.2', '$losses_container144.3']
# DEBUG - dispatch pc=148, inst=STORE_SUBSCR(arg=None, lineno=239)
# DEBUG - stack ['$phi140.0', '$142unary_negative.2', '$losses_container144.3', '$i146.4']
# DEBUG - dispatch pc=152, inst=JUMP_BACKWARD(arg=41, lineno=239)
# DEBUG - stack ['$phi140.0']
# DEBUG - end state. edges=[Edge(pc=72, stack=('$phi140.0',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=282 nstack_initial=1), State(pc_initial=72 nstack_initial=1), State(pc_initial=72 nstack_initial=1)])
# DEBUG - pending: deque([State(pc_initial=72 nstack_initial=1), State(pc_initial=72 nstack_initial=1)])
# DEBUG - pending: deque([State(pc_initial=72 nstack_initial=1)])
# DEBUG - -------------------------Prune PHIs-------------------------
# DEBUG - Used_phis: defaultdict(<class 'set'>,
#             {State(pc_initial=0 nstack_initial=0): set(),
#              State(pc_initial=72 nstack_initial=1): {'$phi72.0'},
#              State(pc_initial=76 nstack_initial=2): {'$phi76.1'},
#              State(pc_initial=116 nstack_initial=1): set(),
#              State(pc_initial=128 nstack_initial=1): set(),
#              State(pc_initial=138 nstack_initial=1): set(),
#              State(pc_initial=140 nstack_initial=1): set(),
#              State(pc_initial=154 nstack_initial=2): set(),
#              State(pc_initial=282 nstack_initial=1): {'$phi282.0'},
#              State(pc_initial=286 nstack_initial=2): {'$phi286.1'},
#              State(pc_initial=374 nstack_initial=2): set()})
# DEBUG - defmap: {'$phi154.1': State(pc_initial=72 nstack_initial=1),
#  '$phi282.0': State(pc_initial=154 nstack_initial=2),
#  '$phi286.1': State(pc_initial=282 nstack_initial=1),
#  '$phi374.1': State(pc_initial=282 nstack_initial=1),
#  '$phi72.0': State(pc_initial=0 nstack_initial=0),
#  '$phi76.1': State(pc_initial=72 nstack_initial=1)}
# DEBUG - phismap: defaultdict(<class 'set'>,
#             {'$phi116.0': {('$phi76.0', State(pc_initial=76 nstack_initial=2))},
#              '$phi128.0': {('$phi76.0', State(pc_initial=76 nstack_initial=2))},
#              '$phi138.0': {('$phi128.0',
#                             State(pc_initial=128 nstack_initial=1))},
#              '$phi140.0': {('$phi128.0',
#                             State(pc_initial=128 nstack_initial=1))},
#              '$phi154.0': {('$phi72.0', State(pc_initial=72 nstack_initial=1))},
#              '$phi154.1': {('$72for_iter.2',
#                             State(pc_initial=72 nstack_initial=1))},
#              '$phi282.0': {('$280get_iter.40',
#                             State(pc_initial=154 nstack_initial=2)),
#                            ('$phi286.0',
#                             State(pc_initial=286 nstack_initial=2))},
#              '$phi286.0': {('$phi282.0',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi286.1': {('$282for_iter.2',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi374.0': {('$phi282.0',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi374.1': {('$282for_iter.2',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi72.0': {('$70get_iter.8',
#                            State(pc_initial=0 nstack_initial=0)),
#                           ('$phi116.0', State(pc_initial=116 nstack_initial=1)),
#                           ('$phi138.0', State(pc_initial=138 nstack_initial=1)),
#                           ('$phi140.0',
#                            State(pc_initial=140 nstack_initial=1))},
#              '$phi76.0': {('$phi72.0', State(pc_initial=72 nstack_initial=1))},
#              '$phi76.1': {('$72for_iter.2',
#                            State(pc_initial=72 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi116.0': {('$phi72.0', State(pc_initial=72 nstack_initial=1))},
#              '$phi128.0': {('$phi72.0', State(pc_initial=72 nstack_initial=1))},
#              '$phi138.0': {('$phi72.0', State(pc_initial=72 nstack_initial=1))},
#              '$phi140.0': {('$phi72.0', State(pc_initial=72 nstack_initial=1))},
#              '$phi154.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0)),
#                            ('$phi116.0',
#                             State(pc_initial=116 nstack_initial=1)),
#                            ('$phi138.0',
#                             State(pc_initial=138 nstack_initial=1)),
#                            ('$phi140.0',
#                             State(pc_initial=140 nstack_initial=1))},
#              '$phi154.1': {('$72for_iter.2',
#                             State(pc_initial=72 nstack_initial=1))},
#              '$phi282.0': {('$280get_iter.40',
#                             State(pc_initial=154 nstack_initial=2)),
#                            ('$phi282.0',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi286.0': {('$280get_iter.40',
#                             State(pc_initial=154 nstack_initial=2))},
#              '$phi286.1': {('$282for_iter.2',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi374.0': {('$280get_iter.40',
#                             State(pc_initial=154 nstack_initial=2))},
#              '$phi374.1': {('$282for_iter.2',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi72.0': {('$70get_iter.8',
#                            State(pc_initial=0 nstack_initial=0)),
#                           ('$phi72.0', State(pc_initial=72 nstack_initial=1))},
#              '$phi76.0': {('$70get_iter.8',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi76.1': {('$72for_iter.2',
#                            State(pc_initial=72 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi116.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi128.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi138.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi140.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi154.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi154.1': {('$72for_iter.2',
#                             State(pc_initial=72 nstack_initial=1))},
#              '$phi282.0': {('$280get_iter.40',
#                             State(pc_initial=154 nstack_initial=2))},
#              '$phi286.0': {('$280get_iter.40',
#                             State(pc_initial=154 nstack_initial=2))},
#              '$phi286.1': {('$282for_iter.2',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi374.0': {('$280get_iter.40',
#                             State(pc_initial=154 nstack_initial=2))},
#              '$phi374.1': {('$282for_iter.2',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi72.0': {('$70get_iter.8',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi76.0': {('$70get_iter.8',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi76.1': {('$72for_iter.2',
#                            State(pc_initial=72 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi116.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi128.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi138.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi140.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi154.0': {('$70get_iter.8',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi154.1': {('$72for_iter.2',
#                             State(pc_initial=72 nstack_initial=1))},
#              '$phi282.0': {('$280get_iter.40',
#                             State(pc_initial=154 nstack_initial=2))},
#              '$phi286.0': {('$280get_iter.40',
#                             State(pc_initial=154 nstack_initial=2))},
#              '$phi286.1': {('$282for_iter.2',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi374.0': {('$280get_iter.40',
#                             State(pc_initial=154 nstack_initial=2))},
#              '$phi374.1': {('$282for_iter.2',
#                             State(pc_initial=282 nstack_initial=1))},
#              '$phi72.0': {('$70get_iter.8',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi76.0': {('$70get_iter.8',
#                            State(pc_initial=0 nstack_initial=0))},
#              '$phi76.1': {('$72for_iter.2',
#                            State(pc_initial=72 nstack_initial=1))}})
# DEBUG - keep phismap: {'$phi282.0': {('$280get_iter.40', State(pc_initial=154 nstack_initial=2))},
#  '$phi286.1': {('$282for_iter.2', State(pc_initial=282 nstack_initial=1))},
#  '$phi72.0': {('$70get_iter.8', State(pc_initial=0 nstack_initial=0))},
#  '$phi76.1': {('$72for_iter.2', State(pc_initial=72 nstack_initial=1))}}
# DEBUG - new_out: defaultdict(<class 'dict'>,
#             {State(pc_initial=0 nstack_initial=0): {'$phi72.0': '$70get_iter.8'},
#              State(pc_initial=72 nstack_initial=1): {'$phi76.1': '$72for_iter.2'},
#              State(pc_initial=154 nstack_initial=2): {'$phi282.0': '$280get_iter.40'},
#              State(pc_initial=282 nstack_initial=1): {'$phi286.1': '$282for_iter.2'}})
# DEBUG - ----------------------DONE Prune PHIs-----------------------
# DEBUG - block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'res': '$close4.0'}), (6, {'item': '$close4.0', 'res': '$6load_attr.1'}), (26, {'value': '$6load_attr.1'}), (28, {'idx': 1, 'res': '$28load_global.2'}), (38, {'item': '$28load_global.2', 'res': '$38load_attr.4'}), (58, {'res': '$const58.5'}), (60, {'res': '$n60.6'}), (62, {'func': '$38load_attr.4', 'args': ['$const58.5', '$n60.6'], 'kw_names': None, 'res': '$62call.7'}), (70, {'value': '$62call.7', 'res': '$70get_iter.8'})), outgoing_phis={'$phi72.0': '$70get_iter.8'}, blockstack=(), active_try_block=None, outgoing_edgepushed={72: ('$70get_iter.8',)})
# DEBUG - block_infos State(pc_initial=72 nstack_initial=1):
# AdaptBlockInfo(insts=((72, {'iterator': '$phi72.0', 'pair': '$72for_iter.1', 'indval': '$72for_iter.2', 'pred': '$72for_iter.3'}),), outgoing_phis={'$phi76.1': '$72for_iter.2'}, blockstack=(), active_try_block=None, outgoing_edgepushed={154: ('$phi72.0', '$72for_iter.2'), 76: ('$phi72.0', '$72for_iter.2')})
# DEBUG - block_infos State(pc_initial=76 nstack_initial=2):
# AdaptBlockInfo(insts=((76, {'value': '$phi76.1'}), (78, {'res': '$close78.2'}), (80, {'res': '$i80.3'}), (82, {'index': '$i80.3', 'target': '$close78.2', 'res': '$82binary_subscr.4'}), (86, {'res': '$close86.5'}), (88, {'res': '$i88.6'}), (90, {'res': '$const90.7'}), (92, {'op': '-', 'lhs': '$i88.6', 'rhs': '$const90.7', 'res': '$binop_sub92.8'}), (96, {'index': '$binop_sub92.8', 'target': '$close86.5', 'res': '$96binary_subscr.9'}), (100, {'op': '-', 'lhs': '$82binary_subscr.4', 'rhs': '$96binary_subscr.9', 'res': '$binop_sub100.10'}), (104, {'value': '$binop_sub100.10'}), (106, {'res': '$delta106.11'}), (108, {'res': '$const108.12'}), (110, {'lhs': '$delta106.11', 'rhs': '$const108.12', 'res': '$110compare_op.13'}), (114, {'pred': '$110compare_op.13'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={116: ('$phi76.0',), 128: ('$phi76.0',)})
# DEBUG - block_infos State(pc_initial=116 nstack_initial=1):
# AdaptBlockInfo(insts=((116, {'res': '$delta116.1'}), (118, {'res': '$gains_container118.2'}), (120, {'res': '$i120.3'}), (122, {'target': '$gains_container118.2', 'index': '$i120.3', 'value': '$delta116.1'}), (126, {})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={72: ('$phi116.0',)})
# DEBUG - block_infos State(pc_initial=128 nstack_initial=1):
# AdaptBlockInfo(insts=((128, {'res': '$delta128.1'}), (130, {'res': '$const130.2'}), (132, {'lhs': '$delta128.1', 'rhs': '$const130.2', 'res': '$132compare_op.3'}), (136, {'pred': '$132compare_op.3'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={138: ('$phi128.0',), 140: ('$phi128.0',)})
# DEBUG - block_infos State(pc_initial=138 nstack_initial=1):
# AdaptBlockInfo(insts=((138, {}),), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={72: ('$phi138.0',)})
# DEBUG - block_infos State(pc_initial=140 nstack_initial=1):
# AdaptBlockInfo(insts=((140, {'res': '$delta140.1'}), (142, {'value': '$delta140.1', 'res': '$142unary_negative.2'}), (144, {'res': '$losses_container144.3'}), (146, {'res': '$i146.4'}), (148, {'target': '$losses_container144.3', 'index': '$i146.4', 'value': '$142unary_negative.2'}), (152, {})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={72: ('$phi140.0',)})
# DEBUG - block_infos State(pc_initial=154 nstack_initial=2):
# AdaptBlockInfo(insts=((156, {'idx': 3, 'res': '$156load_global.2'}), (166, {'res': '$gains_container166.4'}), (168, {'res': '$const168.5'}), (170, {'res': '$period170.6'}), (172, {'res': '$const172.7'}), (174, {'op': '+', 'lhs': '$period170.6', 'rhs': '$const172.7', 'res': '$binop_add174.8'}), (178, {'start': '$const168.5', 'end': '$binop_add174.8', 'container': '$gains_container166.4', 'res': '$178binary_slice.10', 'slicevar': '$178binary_slice.11', 'temp_res': '$178binary_slice.9'}), (180, {'func': '$156load_global.2', 'args': ['$178binary_slice.10'], 'kw_names': None, 'res': '$180call.12'}), (188, {'value': '$180call.12'}), (190, {'idx': 3, 'res': '$190load_global.13'}), (200, {'res': '$losses_container200.15'}), (202, {'res': '$const202.16'}), (204, {'res': '$period204.17'}), (206, {'res': '$const206.18'}), (208, {'op': '+', 'lhs': '$period204.17', 'rhs': '$const206.18', 'res': '$binop_add208.19'}), (212, {'start': '$const202.16', 'end': '$binop_add208.19', 'container': '$losses_container200.15', 'res': '$212binary_slice.21', 'slicevar': '$212binary_slice.22', 'temp_res': '$212binary_slice.20'}), (214, {'func': '$190load_global.13', 'args': ['$212binary_slice.21'], 'kw_names': None, 'res': '$214call.23'}), (222, {'value': '$214call.23'}), (224, {'res': '$const224.24'}), (226, {'res': '$avg_gain226.25'}), (228, {'op': '*', 'lhs': '$const224.24', 'rhs': '$avg_gain226.25', 'res': '$binop_mul228.26'}), (232, {'res': '$avg_gain232.27'}), (234, {'res': '$avg_loss234.28'}), (236, {'op': '+', 'lhs': '$avg_gain232.27', 'rhs': '$avg_loss234.28', 'res': '$binop_add236.29'}), (240, {'op': '/', 'lhs': '$binop_mul228.26', 'rhs': '$binop_add236.29', 'res': '$binop_truediv240.30'}), (244, {'res': '$rsi_container244.31'}), (246, {'res': '$period246.32'}), (248, {'target': '$rsi_container244.31', 'index': '$period246.32', 'value': '$binop_truediv240.30'}), (252, {'idx': 4, 'res': '$252load_global.33'}), (262, {'res': '$period262.35'}), (264, {'res': '$const264.36'}), (266, {'op': '+', 'lhs': '$period262.35', 'rhs': '$const264.36', 'res': '$binop_add266.37'}), (270, {'res': '$n270.38'}), (272, {'func': '$252load_global.33', 'args': ['$binop_add266.37', '$n270.38'], 'kw_names': None, 'res': '$272call.39'}), (280, {'value': '$272call.39', 'res': '$280get_iter.40'})), outgoing_phis={'$phi282.0': '$280get_iter.40'}, blockstack=(), active_try_block=None, outgoing_edgepushed={282: ('$280get_iter.40',)})
# DEBUG - block_infos State(pc_initial=282 nstack_initial=1):
# AdaptBlockInfo(insts=((282, {'iterator': '$phi282.0', 'pair': '$282for_iter.1', 'indval': '$282for_iter.2', 'pred': '$282for_iter.3'}),), outgoing_phis={'$phi286.1': '$282for_iter.2'}, blockstack=(), active_try_block=None, outgoing_edgepushed={374: ('$phi282.0', '$282for_iter.2'), 286: ('$phi282.0', '$282for_iter.2')})
# DEBUG - block_infos State(pc_initial=286 nstack_initial=2):
# AdaptBlockInfo(insts=((286, {'value': '$phi286.1'}), (288, {'res': '$avg_gain288.2'}), (290, {'res': '$p_1290.3'}), (292, {'op': '*', 'lhs': '$avg_gain288.2', 'rhs': '$p_1290.3', 'res': '$binop_mul292.4'}), (296, {'res': '$gains_container296.5'}), (298, {'res': '$i298.6'}), (300, {'index': '$i298.6', 'target': '$gains_container296.5', 'res': '$300binary_subscr.7'}), (304, {'op': '+', 'lhs': '$binop_mul292.4', 'rhs': '$300binary_subscr.7', 'res': '$binop_add304.8'}), (308, {'res': '$period308.9'}), (310, {'op': '/', 'lhs': '$binop_add304.8', 'rhs': '$period308.9', 'res': '$binop_truediv310.10'}), (314, {'value': '$binop_truediv310.10'}), (316, {'res': '$avg_loss316.11'}), (318, {'res': '$p_1318.12'}), (320, {'op': '*', 'lhs': '$avg_loss316.11', 'rhs': '$p_1318.12', 'res': '$binop_mul320.13'}), (324, {'res': '$losses_container324.14'}), (326, {'res': '$i326.15'}), (328, {'index': '$i326.15', 'target': '$losses_container324.14', 'res': '$328binary_subscr.16'}), (332, {'op': '+', 'lhs': '$binop_mul320.13', 'rhs': '$328binary_subscr.16', 'res': '$binop_add332.17'}), (336, {'res': '$period336.18'}), (338, {'op': '/', 'lhs': '$binop_add332.17', 'rhs': '$period336.18', 'res': '$binop_truediv338.19'}), (342, {'value': '$binop_truediv338.19'}), (344, {'res': '$const344.20'}), (346, {'res': '$avg_gain346.21'}), (348, {'op': '*', 'lhs': '$const344.20', 'rhs': '$avg_gain346.21', 'res': '$binop_mul348.22'}), (352, {'res': '$avg_gain352.23'}), (354, {'res': '$avg_loss354.24'}), (356, {'op': '+', 'lhs': '$avg_gain352.23', 'rhs': '$avg_loss354.24', 'res': '$binop_add356.25'}), (360, {'op': '/', 'lhs': '$binop_mul348.22', 'rhs': '$binop_add356.25', 'res': '$binop_truediv360.26'}), (364, {'res': '$rsi_container364.27'}), (366, {'res': '$i366.28'}), (368, {'target': '$rsi_container364.27', 'index': '$i366.28', 'value': '$binop_truediv360.26'}), (372, {})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={282: ('$phi286.0',)})
# DEBUG - block_infos State(pc_initial=374 nstack_initial=2):
# AdaptBlockInfo(insts=((376, {'res': '$rsi_container376.2'}), (378, {'res': '$avg_gain378.3'}), (380, {'res': '$avg_loss380.4'}), (382, {'res': '$close382.5'}), (384, {'res': '$const384.6'}), (386, {'index': '$const384.6', 'target': '$close382.5', 'res': '$386binary_subscr.7'}), (390, {'items': ['$rsi_container376.2', '$avg_gain378.3', '$avg_loss380.4', '$386binary_subscr.7'], 'res': '$390build_tuple.8'}), (392, {'retval': '$390build_tuple.8', 'castval': '$392return_value.9'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG - label 0:
#     close = arg(0, name=close)               ['close']
#     rsi_container = arg(1, name=rsi_container) ['rsi_container']
#     gains_container = arg(2, name=gains_container) ['gains_container']
#     losses_container = arg(3, name=losses_container) ['losses_container']
#     period = arg(4, name=period)             ['period']
#     p_1 = arg(5, name=p_1)                   ['p_1']
#     n = getattr(value=close, attr=size)      ['close', 'n']
#     $28load_global.2 = global(nb: <module 'numba' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numba\\__init__.py'>) ['$28load_global.2']
#     $38load_attr.4 = getattr(value=$28load_global.2, attr=prange) ['$28load_global.2', '$38load_attr.4']
#     $const58.5 = const(int, 1)               ['$const58.5']
#     $62call.7 = call $38load_attr.4($const58.5, n, func=$38load_attr.4, args=[Var($const58.5, numba.py:234), Var(n, numba.py:231)], kws=(), vararg=None, varkwarg=None, target=None) ['$38load_attr.4', '$62call.7', '$const58.5', 'n']
#     $70get_iter.8 = getiter(value=$62call.7) ['$62call.7', '$70get_iter.8']
#     $phi72.0 = $70get_iter.8                 ['$70get_iter.8', '$phi72.0']
#     jump 72                                  []
# label 72:
#     $72for_iter.1 = iternext(value=$phi72.0) ['$72for_iter.1', '$phi72.0']
#     $72for_iter.2 = pair_first(value=$72for_iter.1) ['$72for_iter.1', '$72for_iter.2']
#     $72for_iter.3 = pair_second(value=$72for_iter.1) ['$72for_iter.1', '$72for_iter.3']
#     $phi76.1 = $72for_iter.2                 ['$72for_iter.2', '$phi76.1']
#     branch $72for_iter.3, 76, 154            ['$72for_iter.3']
# label 76:
#     i = $phi76.1                             ['$phi76.1', 'i']
#     $82binary_subscr.4 = getitem(value=close, index=i, fn=<built-in function getitem>) ['$82binary_subscr.4', 'close', 'i']
#     $const90.7 = const(int, 1)               ['$const90.7']
#     $binop_sub92.8 = i - $const90.7          ['$binop_sub92.8', '$const90.7', 'i']
#     $96binary_subscr.9 = getitem(value=close, index=$binop_sub92.8, fn=<built-in function getitem>) ['$96binary_subscr.9', '$binop_sub92.8', 'close']
#     delta = $82binary_subscr.4 - $96binary_subscr.9 ['$82binary_subscr.4', '$96binary_subscr.9', 'delta']
#     $const108.12 = const(int, 0)             ['$const108.12']
#     $110compare_op.13 = delta > $const108.12 ['$110compare_op.13', '$const108.12', 'delta']
#     bool114 = global(bool: <class 'bool'>)   ['bool114']
#     $114pred = call bool114($110compare_op.13, func=bool114, args=(Var($110compare_op.13, numba.py:236),), kws=(), vararg=None, varkwarg=None, target=None) ['$110compare_op.13', '$114pred', 'bool114']
#     branch $114pred, 116, 128                ['$114pred']
# label 116:
#     gains_container[i] = delta               ['delta', 'gains_container', 'i']
#     jump 72                                  []
# label 128:
#     $const130.2 = const(int, 0)              ['$const130.2']
#     $132compare_op.3 = delta < $const130.2   ['$132compare_op.3', '$const130.2', 'delta']
#     bool136 = global(bool: <class 'bool'>)   ['bool136']
#     $136pred = call bool136($132compare_op.3, func=bool136, args=(Var($132compare_op.3, numba.py:238),), kws=(), vararg=None, varkwarg=None, target=None) ['$132compare_op.3', '$136pred', 'bool136']
#     branch $136pred, 140, 138                ['$136pred']
# label 138:
#     jump 72                                  []
# label 140:
#     $142unary_negative.2 = unary(fn=<built-in function neg>, value=delta) ['$142unary_negative.2', 'delta']
#     losses_container[i] = $142unary_negative.2 ['$142unary_negative.2', 'i', 'losses_container']
#     jump 72                                  []
# label 154:
#     $156load_global.2 = global(_mean: CPUDispatcher(<function _mean at 0x000002207F6ABA60>)) ['$156load_global.2']
#     $const168.5 = const(int, 1)              ['$const168.5']
#     $const172.7 = const(int, 1)              ['$const172.7']
#     $binop_add174.8 = period + $const172.7   ['$binop_add174.8', '$const172.7', 'period']
#     $178binary_slice.11 = global(slice: <class 'slice'>) ['$178binary_slice.11']
#     $178binary_slice.9 = call $178binary_slice.11($const168.5, $binop_add174.8, func=$178binary_slice.11, args=(Var($const168.5, numba.py:241), Var($binop_add174.8, numba.py:241)), kws=(), vararg=None, varkwarg=None, target=None) ['$178binary_slice.11', '$178binary_slice.9', '$binop_add174.8', '$const168.5']
#     $178binary_slice.10 = getitem(value=gains_container, index=$178binary_slice.9, fn=<built-in function getitem>) ['$178binary_slice.10', '$178binary_slice.9', 'gains_container']
#     avg_gain = call $156load_global.2($178binary_slice.10, func=$156load_global.2, args=[Var($178binary_slice.10, numba.py:241)], kws=(), vararg=None, varkwarg=None, target=None) ['$156load_global.2', '$178binary_slice.10', 'avg_gain']
#     $190load_global.13 = global(_mean: CPUDispatcher(<function _mean at 0x000002207F6ABA60>)) ['$190load_global.13']
#     $const202.16 = const(int, 1)             ['$const202.16']
#     $const206.18 = const(int, 1)             ['$const206.18']
#     $binop_add208.19 = period + $const206.18 ['$binop_add208.19', '$const206.18', 'period']
#     $212binary_slice.22 = global(slice: <class 'slice'>) ['$212binary_slice.22']
#     $212binary_slice.20 = call $212binary_slice.22($const202.16, $binop_add208.19, func=$212binary_slice.22, args=(Var($const202.16, numba.py:242), Var($binop_add208.19, numba.py:242)), kws=(), vararg=None, varkwarg=None, target=None) ['$212binary_slice.20', '$212binary_slice.22', '$binop_add208.19', '$const202.16']
#     $212binary_slice.21 = getitem(value=losses_container, index=$212binary_slice.20, fn=<built-in function getitem>) ['$212binary_slice.20', '$212binary_slice.21', 'losses_container']
#     avg_loss = call $190load_global.13($212binary_slice.21, func=$190load_global.13, args=[Var($212binary_slice.21, numba.py:242)], kws=(), vararg=None, varkwarg=None, target=None) ['$190load_global.13', '$212binary_slice.21', 'avg_loss']
#     $const224.24 = const(int, 100)           ['$const224.24']
#     $binop_mul228.26 = $const224.24 * avg_gain ['$binop_mul228.26', '$const224.24', 'avg_gain']
#     $binop_add236.29 = avg_gain + avg_loss   ['$binop_add236.29', 'avg_gain', 'avg_loss']
#     $binop_truediv240.30 = $binop_mul228.26 / $binop_add236.29 ['$binop_add236.29', '$binop_mul228.26', '$binop_truediv240.30']
# ...
# DEBUG - stack []
# DEBUG - dispatch pc=4, inst=LOAD_GLOBAL(arg=0, lineno=2)
# DEBUG - stack []
# DEBUG - dispatch pc=14, inst=LOAD_ATTR(arg=2, lineno=2)
# DEBUG - stack ['$4load_global.0']
# DEBUG - dispatch pc=34, inst=LOAD_ATTR(arg=4, lineno=2)
# DEBUG - stack ['$14load_attr.1']
# DEBUG - dispatch pc=54, inst=LOAD_ATTR(arg=6, lineno=2)
# DEBUG - stack ['$34load_attr.2']
# DEBUG - dispatch pc=74, inst=LOAD_ATTR(arg=9, lineno=2)
# DEBUG - stack ['$54load_attr.3']
# DEBUG - dispatch pc=94, inst=CALL(arg=0, lineno=2)
# DEBUG - stack ['$null$74.4', '$74load_attr.5']
# DEBUG - dispatch pc=102, inst=STORE_FAST(arg=3, lineno=2)
# DEBUG - stack ['$94call.6']
# DEBUG - dispatch pc=104, inst=LOAD_FAST(arg=2, lineno=3)
# DEBUG - stack []
# DEBUG - dispatch pc=106, inst=LOAD_FAST(arg=3, lineno=3)
# DEBUG - stack ['$__mean__v3__sum_2__arr104.7']
# DEBUG - dispatch pc=108, inst=BINARY_SUBSCR(arg=None, lineno=3)
# DEBUG - stack ['$__mean__v3__sum_2__arr104.7', '$ParallelAcceleratorGufuncThreadId106.8']
# DEBUG - dispatch pc=112, inst=STORE_FAST(arg=4, lineno=3)
# DEBUG - stack ['$108binary_subscr.9']
# DEBUG - dispatch pc=114, inst=LOAD_GLOBAL(arg=11, lineno=4)
# DEBUG - stack []
# DEBUG - dispatch pc=124, inst=LOAD_FAST(arg=0, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10']
# DEBUG - dispatch pc=126, inst=LOAD_CONST(arg=1, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$sched124.12']
# DEBUG - dispatch pc=128, inst=BINARY_SUBSCR(arg=None, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$sched124.12', '$const126.13']
# DEBUG - dispatch pc=132, inst=LOAD_FAST(arg=0, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$128binary_subscr.14']
# DEBUG - dispatch pc=134, inst=LOAD_CONST(arg=2, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$128binary_subscr.14', '$sched132.15']
# DEBUG - dispatch pc=136, inst=BINARY_SUBSCR(arg=None, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$128binary_subscr.14', '$sched132.15', '$const134.16']
# DEBUG - dispatch pc=140, inst=LOAD_GLOBAL(arg=2, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$128binary_subscr.14', '$136binary_subscr.17']
# DEBUG - dispatch pc=150, inst=LOAD_ATTR(arg=13, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$128binary_subscr.14', '$136binary_subscr.17', '$140load_global.18']
# DEBUG - dispatch pc=170, inst=LOAD_CONST(arg=2, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$128binary_subscr.14', '$136binary_subscr.17', '$null$150.19', '$150load_attr.20']
# DEBUG - dispatch pc=172, inst=CALL(arg=1, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$128binary_subscr.14', '$136binary_subscr.17', '$null$150.19', '$150load_attr.20', '$const170.21']
# DEBUG - dispatch pc=180, inst=BINARY_OP(arg=0, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$128binary_subscr.14', '$136binary_subscr.17', '$172call.22']
# DEBUG - dispatch pc=184, inst=CALL(arg=2, lineno=4)
# DEBUG - stack ['$null$114.11', '$114load_global.10', '$128binary_subscr.14', '$binop_add180.23']
# DEBUG - dispatch pc=192, inst=GET_ITER(arg=None, lineno=4)
# DEBUG - stack ['$184call.24']
# DEBUG - end state. edges=[Edge(pc=194, stack=('$192get_iter.25',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=194 nstack_initial=1)])
# DEBUG - stack: ['$phi194.0']
# DEBUG - state.pc_initial: State(pc_initial=194 nstack_initial=1)
# DEBUG - dispatch pc=194, inst=FOR_ITER(arg=4, lineno=4)
# DEBUG - stack ['$phi194.0']
# DEBUG - end state. edges=[Edge(pc=206, stack=('$phi194.0', '$194for_iter.2'), blockstack=(), npush=0), Edge(pc=198, stack=('$phi194.0', '$194for_iter.2'), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=206 nstack_initial=2), State(pc_initial=198 nstack_initial=2)])
# DEBUG - stack: ['$phi206.0', '$phi206.1']
# DEBUG - state.pc_initial: State(pc_initial=206 nstack_initial=2)
# DEBUG - dispatch pc=206, inst=END_FOR(arg=None, lineno=4)
# DEBUG - stack ['$phi206.0', '$phi206.1']
# DEBUG - dispatch pc=208, inst=LOAD_FAST(arg=4, lineno=6)
# DEBUG - stack []
# DEBUG - dispatch pc=210, inst=LOAD_FAST(arg=2, lineno=6)
# DEBUG - stack ['$__mean__v3__sum_2208.2']
# DEBUG - dispatch pc=212, inst=LOAD_FAST(arg=3, lineno=6)
# DEBUG - stack ['$__mean__v3__sum_2208.2', '$__mean__v3__sum_2__arr210.3']
# DEBUG - dispatch pc=214, inst=STORE_SUBSCR(arg=None, lineno=6)
# DEBUG - stack ['$__mean__v3__sum_2208.2', '$__mean__v3__sum_2__arr210.3', '$ParallelAcceleratorGufuncThreadId212.4']
# DEBUG - dispatch pc=218, inst=RETURN_CONST(arg=0, lineno=7)
# DEBUG - stack []
# DEBUG - end state. edges=[]
# DEBUG - pending: deque([State(pc_initial=198 nstack_initial=2)])
# DEBUG - stack: ['$phi198.0', '$phi198.1']
# DEBUG - state.pc_initial: State(pc_initial=198 nstack_initial=2)
# DEBUG - dispatch pc=198, inst=STORE_FAST(arg=5, lineno=4)
# DEBUG - stack ['$phi198.0', '$phi198.1']
# DEBUG - dispatch pc=200, inst=LOAD_CONST(arg=1, lineno=5)
# DEBUG - stack ['$phi198.0']
# DEBUG - dispatch pc=202, inst=STORE_FAST(arg=6, lineno=5)
# DEBUG - stack ['$phi198.0', '$const200.2']
# DEBUG - dispatch pc=204, inst=JUMP_BACKWARD(arg=6, lineno=5)
# DEBUG - stack ['$phi198.0']
# DEBUG - end state. edges=[Edge(pc=194, stack=('$phi198.0',), blockstack=(), npush=0)]
# DEBUG - pending: deque([State(pc_initial=194 nstack_initial=1)])
# DEBUG - -------------------------Prune PHIs-------------------------
# DEBUG - Used_phis: defaultdict(<class 'set'>,
#             {State(pc_initial=0 nstack_initial=0): set(),
#              State(pc_initial=194 nstack_initial=1): {'$phi194.0'},
#              State(pc_initial=198 nstack_initial=2): {'$phi198.1'},
#              State(pc_initial=206 nstack_initial=2): set()})
# DEBUG - defmap: {'$phi194.0': State(pc_initial=0 nstack_initial=0),
#  '$phi198.1': State(pc_initial=194 nstack_initial=1),
#  '$phi206.1': State(pc_initial=194 nstack_initial=1)}
# DEBUG - phismap: defaultdict(<class 'set'>,
#             {'$phi194.0': {('$192get_iter.25',
#                             State(pc_initial=0 nstack_initial=0)),
#                            ('$phi198.0',
#                             State(pc_initial=198 nstack_initial=2))},
#              '$phi198.0': {('$phi194.0',
#                             State(pc_initial=194 nstack_initial=1))},
#              '$phi198.1': {('$194for_iter.2',
#                             State(pc_initial=194 nstack_initial=1))},
#              '$phi206.0': {('$phi194.0',
#                             State(pc_initial=194 nstack_initial=1))},
#              '$phi206.1': {('$194for_iter.2',
#                             State(pc_initial=194 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi194.0': {('$192get_iter.25',
#                             State(pc_initial=0 nstack_initial=0)),
#                            ('$phi194.0',
#                             State(pc_initial=194 nstack_initial=1))},
#              '$phi198.0': {('$192get_iter.25',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi198.1': {('$194for_iter.2',
#                             State(pc_initial=194 nstack_initial=1))},
#              '$phi206.0': {('$192get_iter.25',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi206.1': {('$194for_iter.2',
#                             State(pc_initial=194 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi194.0': {('$192get_iter.25',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi198.0': {('$192get_iter.25',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi198.1': {('$194for_iter.2',
#                             State(pc_initial=194 nstack_initial=1))},
#              '$phi206.0': {('$192get_iter.25',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi206.1': {('$194for_iter.2',
#                             State(pc_initial=194 nstack_initial=1))}})
# DEBUG - changing phismap: defaultdict(<class 'set'>,
#             {'$phi194.0': {('$192get_iter.25',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi198.0': {('$192get_iter.25',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi198.1': {('$194for_iter.2',
#                             State(pc_initial=194 nstack_initial=1))},
#              '$phi206.0': {('$192get_iter.25',
#                             State(pc_initial=0 nstack_initial=0))},
#              '$phi206.1': {('$194for_iter.2',
#                             State(pc_initial=194 nstack_initial=1))}})
# DEBUG - keep phismap: {'$phi194.0': {('$192get_iter.25', State(pc_initial=0 nstack_initial=0))},
#  '$phi198.1': {('$194for_iter.2', State(pc_initial=194 nstack_initial=1))}}
# DEBUG - new_out: defaultdict(<class 'dict'>,
#             {State(pc_initial=0 nstack_initial=0): {'$phi194.0': '$192get_iter.25'},
#              State(pc_initial=194 nstack_initial=1): {'$phi198.1': '$194for_iter.2'}})
# DEBUG - ----------------------DONE Prune PHIs-----------------------
# DEBUG - block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {}), (4, {'idx': 0, 'res': '$4load_global.0'}), (14, {'item': '$4load_global.0', 'res': '$14load_attr.1'}), (34, {'item': '$14load_attr.1', 'res': '$34load_attr.2'}), (54, {'item': '$34load_attr.2', 'res': '$54load_attr.3'}), (74, {'item': '$54load_attr.3', 'res': '$74load_attr.5'}), (94, {'func': '$74load_attr.5', 'args': [], 'kw_names': None, 'res': '$94call.6'}), (102, {'value': '$94call.6'}), (104, {'res': '$__mean__v3__sum_2__arr104.7'}), (106, {'res': '$ParallelAcceleratorGufuncThreadId106.8'}), (108, {'index': '$ParallelAcceleratorGufuncThreadId106.8', 'target': '$__mean__v3__sum_2__arr104.7', 'res': '$108binary_subscr.9'}), (112, {'value': '$108binary_subscr.9'}), (114, {'idx': 5, 'res': '$114load_global.10'}), (124, {'res': '$sched124.12'}), (126, {'res': '$const126.13'}), (128, {'index': '$const126.13', 'target': '$sched124.12', 'res': '$128binary_subscr.14'}), (132, {'res': '$sched132.15'}), (134, {'res': '$const134.16'}), (136, {'index': '$const134.16', 'target': '$sched132.15', 'res': '$136binary_subscr.17'}), (140, {'idx': 1, 'res': '$140load_global.18'}), (150, {'item': '$140load_global.18', 'res': '$150load_attr.20'}), (170, {'res': '$const170.21'}), (172, {'func': '$150load_attr.20', 'args': ['$const170.21'], 'kw_names': None, 'res': '$172call.22'}), (180, {'op': '+', 'lhs': '$136binary_subscr.17', 'rhs': '$172call.22', 'res': '$binop_add180.23'}), (184, {'func': '$114load_global.10', 'args': ['$128binary_subscr.14', '$binop_add180.23'], 'kw_names': None, 'res': '$184call.24'}), (192, {'value': '$184call.24', 'res': '$192get_iter.25'})), outgoing_phis={'$phi194.0': '$192get_iter.25'}, blockstack=(), active_try_block=None, outgoing_edgepushed={194: ('$192get_iter.25',)})
# DEBUG - block_infos State(pc_initial=194 nstack_initial=1):
# AdaptBlockInfo(insts=((194, {'iterator': '$phi194.0', 'pair': '$194for_iter.1', 'indval': '$194for_iter.2', 'pred': '$194for_iter.3'}),), outgoing_phis={'$phi198.1': '$194for_iter.2'}, blockstack=(), active_try_block=None, outgoing_edgepushed={206: ('$phi194.0', '$194for_iter.2'), 198: ('$phi194.0', '$194for_iter.2')})
# DEBUG - block_infos State(pc_initial=198 nstack_initial=2):
# AdaptBlockInfo(insts=((198, {'value': '$phi198.1'}), (200, {'res': '$const200.2'}), (202, {'value': '$const200.2'}), (204, {})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={194: ('$phi198.0',)})
# DEBUG - block_infos State(pc_initial=206 nstack_initial=2):
# AdaptBlockInfo(insts=((208, {'res': '$__mean__v3__sum_2208.2'}), (210, {'res': '$__mean__v3__sum_2__arr210.3'}), (212, {'res': '$ParallelAcceleratorGufuncThreadId212.4'}), (214, {'target': '$__mean__v3__sum_2__arr210.3', 'index': '$ParallelAcceleratorGufuncThreadId212.4', 'value': '$__mean__v3__sum_2208.2'}), (218, {'retval': '$const218.5', 'castval': '$218return_const.6'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG - label 0:
#     sched = arg(0, name=sched)               ['sched']
#     ___mean__v3__arr_29 = arg(1, name=___mean__v3__arr_29) ['___mean__v3__arr_29']
#     __mean__v3__sum_2__arr = arg(2, name=__mean__v3__sum_2__arr) ['__mean__v3__sum_2__arr']
#     $4load_global.0 = global(numba: <module 'numba' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numba\\__init__.py'>) ['$4load_global.0']
#     $14load_attr.1 = getattr(value=$4load_global.0, attr=np) ['$14load_attr.1', '$4load_global.0']
#     $34load_attr.2 = getattr(value=$14load_attr.1, attr=ufunc) ['$14load_attr.1', '$34load_attr.2']
#     $54load_attr.3 = getattr(value=$34load_attr.2, attr=parallel) ['$34load_attr.2', '$54load_attr.3']
#     $74load_attr.5 = getattr(value=$54load_attr.3, attr=_iget_thread_id) ['$54load_attr.3', '$74load_attr.5']
#     ParallelAcceleratorGufuncThreadId = call $74load_attr.5(func=$74load_attr.5, args=[], kws=(), vararg=None, varkwarg=None, target=None) ['$74load_attr.5', 'ParallelAcceleratorGufuncThreadId']
#     __mean__v3__sum_2 = getitem(value=__mean__v3__sum_2__arr, index=ParallelAcceleratorGufuncThreadId, fn=<built-in function getitem>) ['ParallelAcceleratorGufuncThreadId', '__mean__v3__sum_2', '__mean__v3__sum_2__arr']
#     $114load_global.10 = global(range: <class 'range'>) ['$114load_global.10']
#     $const126.13 = const(int, 0)             ['$const126.13']
#     $128binary_subscr.14 = getitem(value=sched, index=$const126.13, fn=<built-in function getitem>) ['$128binary_subscr.14', '$const126.13', 'sched']
#     $const134.16 = const(int, 1)             ['$const134.16']
#     $136binary_subscr.17 = getitem(value=sched, index=$const134.16, fn=<built-in function getitem>) ['$136binary_subscr.17', '$const134.16', 'sched']
#     $140load_global.18 = global(np: <module 'numpy' from 'c:\\Users\\tomsr\\Documents\\Code\\production\\pypi\\rolling-ta\\.rolling-ta\\Lib\\site-packages\\numpy\\__init__.py'>) ['$140load_global.18']
#     $150load_attr.20 = getattr(value=$140load_global.18, attr=uint8) ['$140load_global.18', '$150load_attr.20']
#     $const170.21 = const(int, 1)             ['$const170.21']
#     $172call.22 = call $150load_attr.20($const170.21, func=$150load_attr.20, args=[Var($const170.21, <string>:4)], kws=(), vararg=None, varkwarg=None, target=None) ['$150load_attr.20', '$172call.22', '$const170.21']
#     $binop_add180.23 = $136binary_subscr.17 + $172call.22 ['$136binary_subscr.17', '$172call.22', '$binop_add180.23']
#     $184call.24 = call $114load_global.10($128binary_subscr.14, $binop_add180.23, func=$114load_global.10, args=[Var($128binary_subscr.14, <string>:4), Var($binop_add180.23, <string>:4)], kws=(), vararg=None, varkwarg=None, target=None) ['$114load_global.10', '$128binary_subscr.14', '$184call.24', '$binop_add180.23']
#     $192get_iter.25 = getiter(value=$184call.24) ['$184call.24', '$192get_iter.25']
#     $phi194.0 = $192get_iter.25              ['$192get_iter.25', '$phi194.0']
#     jump 194                                 []
# label 194:
#     $194for_iter.1 = iternext(value=$phi194.0) ['$194for_iter.1', '$phi194.0']
#     $194for_iter.2 = pair_first(value=$194for_iter.1) ['$194for_iter.1', '$194for_iter.2']
#     $194for_iter.3 = pair_second(value=$194for_iter.1) ['$194for_iter.1', '$194for_iter.3']
#     $phi198.1 = $194for_iter.2               ['$194for_iter.2', '$phi198.1']
#     branch $194for_iter.3, 198, 206          ['$194for_iter.3']
# label 198:
#     parfor__index_20 = $phi198.1             ['$phi198.1', 'parfor__index_20']
#     __sentinel__0 = const(int, 0)            ['__sentinel__0']
#     jump 194                                 []
# label 206:
#     __mean__v3__sum_2__arr[ParallelAcceleratorGufuncThreadId] = __mean__v3__sum_2 ['ParallelAcceleratorGufuncThreadId', '__mean__v3__sum_2', '__mean__v3__sum_2__arr']
#     $const218.5 = const(NoneType, None)      ['$const218.5']
#     $218return_const.6 = cast(value=$const218.5) ['$218return_const.6', '$const218.5']
#     return $218return_const.6                ['$218return_const.6']

# %%
# %%timeit
rsi = RSIIndicator(data["close"], 14)
rsi.rsi()
# Out:
# 1.01 ms ± 33.9 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
NumbaRSI(data, memory=False)
# Out:
# 96.2 μs ± 665 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
